# %%
import pandas as pd
import numpy as np

# %%
Job_info = 'GC-200779_R1'
shrimp_number = 'SN_0002'

# %% [markdown]
# # Importing the Data

# %%
df1 = pd.read_csv(r'C:\Users\adeni\OneDrive - KLX Energy\Overview Data\WT-200779run1\SN0002_CH1.txt', delimiter = ' ')
df2 = pd.read_csv(r'C:\Users\adeni\OneDrive - KLX Energy\Overview Data\WT-200779run1\SN0002_CH2.txt', delimiter = ' ')
df =pd.concat([df1,df2])

# %% [markdown]
# # Preprocessing and Cleaning the Data

# %%
df.head()
# Out:
#    Unnamed: 0  MROAVG  LROAVG  ROMIN  ROMAX  ZRANGE  YRANGE  TEMP  *
# 0         NaN      12      17    141    198     131     135    24  0
# 1         NaN      12      64    193    198       4       5    24  0
# 2         NaN      12      68    193    199       4       4    24  0
# 3         NaN      12      71    193    198       5       5    24  0
# 4         NaN      12      63    193    199       5       5    24  0

# %%
df.drop(columns = ['Unnamed: 0'], inplace = True)

# %%
#df.drop(columns = ['Date'], inplace=True)

# %%
#df.drop(columns = ['Time'], inplace=True)

# %%
df.drop(df[df['TEMP'] > 254].index, inplace = True)

# %%
df
# Out:
#        MROAVG  LROAVG  ROMIN  ROMAX  ZRANGE  YRANGE  TEMP  *
# 0          12      17    141    198     131     135    24  0
# 1          12      64    193    198       4       5    24  0
# 2          12      68    193    199       4       4    24  0
# 3          12      71    193    198       5       5    24  0
# 4          12      63    193    199       5       5    24  0
# ...       ...     ...    ...    ...     ...     ...   ... ..
# 19904      11     255    133    197     131     129    20  0
# 19905      12      58    192    198       5       5    20  0
# 19906      12      58    192    198       6       4    20  0
# 19907      12      58    193    199       6       5    19  0
# 19908      12      57    192    198       5       4    20  0
#
# [1058331 rows x 8 columns]

# %%
df.describe()
# Out:
#              MROAVG        LROAVG         ROMIN         ROMAX        ZRANGE  \
# count  1.058331e+06  1.058331e+06  1.058331e+06  1.058331e+06  1.058331e+06
# mean   1.106796e+01  9.129260e+01  1.751512e+02  1.897362e+02  9.723866e+00
# std    1.291374e+00  5.951358e+01  2.307183e+01  1.484001e+01  5.712944e+00
# min    0.000000e+00  0.000000e+00  0.000000e+00  2.300000e+01  3.000000e+00
# 25%    1.000000e+01  6.000000e+01  1.530000e+02  1.770000e+02  5.000000e+00
# 50%    1.200000e+01  6.600000e+01  1.920000e+02  1.990000e+02  7.000000e+00
# 75%    1.200000e+01  1.070000e+02  1.930000e+02  1.990000e+02  1.400000e+01
# max    1.500000e+01  2.550000e+02  2.140000e+02  2.550000e+02  1.340000e+02
#
#              YRANGE          TEMP             *
# count  1.058331e+06  1.058331e+06  1.058331e+06
# mean   1.636343e+01  8.025222e+01  7.029937e-03
# std    1.376947e+01  3.926130e+01  6.744973e-01
# min    3.000000e+00  1.500000e+01  0.000000e+00
# 25%    5.000000e+00  4.800000e+01  0.000000e+00
# 50%    1.200000e+01  7.600000e+01  0.000000e+00
# 75%    2.600000e+01  1.230000e+02  0.000000e+00
# max    1.390000e+02  1.510000e+02  1.280000e+02

# %%
df.drop(df[df['MROAVG'] > 254].index, inplace = True)

# %%
#df.drop(df[df['LROAVG'] > 254].index, inplace = True)

# %%
#df.drop(df[df['LROAVG'] > 254].index, inplace = True)

# %%
df.describe()
# Out:
#              MROAVG        LROAVG         ROMIN         ROMAX        ZRANGE  \
# count  1.058331e+06  1.058331e+06  1.058331e+06  1.058331e+06  1.058331e+06
# mean   1.106796e+01  9.129260e+01  1.751512e+02  1.897362e+02  9.723866e+00
# std    1.291374e+00  5.951358e+01  2.307183e+01  1.484001e+01  5.712944e+00
# min    0.000000e+00  0.000000e+00  0.000000e+00  2.300000e+01  3.000000e+00
# 25%    1.000000e+01  6.000000e+01  1.530000e+02  1.770000e+02  5.000000e+00
# 50%    1.200000e+01  6.600000e+01  1.920000e+02  1.990000e+02  7.000000e+00
# 75%    1.200000e+01  1.070000e+02  1.930000e+02  1.990000e+02  1.400000e+01
# max    1.500000e+01  2.550000e+02  2.140000e+02  2.550000e+02  1.340000e+02
#
#              YRANGE          TEMP             *
# count  1.058331e+06  1.058331e+06  1.058331e+06
# mean   1.636343e+01  8.025222e+01  7.029937e-03
# std    1.376947e+01  3.926130e+01  6.744973e-01
# min    3.000000e+00  1.500000e+01  0.000000e+00
# 25%    5.000000e+00  4.800000e+01  0.000000e+00
# 50%    1.200000e+01  7.600000e+01  0.000000e+00
# 75%    2.600000e+01  1.230000e+02  0.000000e+00
# max    1.390000e+02  1.510000e+02  1.280000e+02

# %%
df.loc[df['LROAVG'] == 255].count
# Out:
# <bound method DataFrame.count of         MROAVG  LROAVG  ROMIN  ROMAX  ZRANGE  YRANGE  TEMP  *
# 113226      12     255    195    221       5       9    16  0
# 134390      11     255    174    198       5       6    36  0
# 134663      10     255    170    187       6      19    36  0
# 134833      10     255    164    194       6       8    36  0
# 134862      10     255    162    187       6      15    36  0
# ...        ...     ...    ...    ...     ...     ...   ... ..
# 930904       9     255    153    164      15      39   128  0
# 931301       9     255    155    166      21      62   128  0
# 931538       9     255    153    169      30      45   128  0
# 935118       7     255    123    133      10      47   128  0
# 19904       11     255    133    197     131     129    20  0
#
# [1925 rows x 8 columns]>

# %%
df['BHA-RPM'] = ((3117 - ((256 * df['MROAVG']) + df['LROAVG']))/ 7.305)

# %%
df['Z-Gs'] = df['ZRANGE'] / 7.75

# %%
df['XY-Gs'] = df['YRANGE']/7.75

# %%
df['BHA-RPM'].mean()
# Out:
# 26.32569447801332

# %%
df
# Out:
#        MROAVG  LROAVG  ROMIN  ROMAX  ZRANGE  YRANGE  TEMP  *   BHA-RPM  \
# 0          12      17    141    198     131     135    24  0  3.832991
# 1          12      64    193    198       4       5    24  0 -2.600958
# 2          12      68    193    199       4       4    24  0 -3.148528
# 3          12      71    193    198       5       5    24  0 -3.559206
# 4          12      63    193    199       5       5    24  0 -2.464066
# ...       ...     ...    ...    ...     ...     ...   ... ..       ...
# 19904      11     255    133    197     131     129    20  0  6.297057
# 19905      12      58    192    198       5       5    20  0 -1.779603
# 19906      12      58    192    198       6       4    20  0 -1.779603
# 19907      12      58    193    199       6       5    19  0 -1.779603
# 19908      12      57    192    198       5       4    20  0 -1.642710
#
#             Z-Gs      XY-Gs
# 0      16.903226  17.419355
# 1       0.516129   0.645161
# 2       0.516129   0.516129
# 3       0.645161   0.645161
# 4       0.645161   0.645161
# ...          ...        ...
# 19904  16.903226  16.645161
# 19905   0.645161   0.645161
# 19906   0.774194   0.516129
# 19907   0.774194   0.645161
# 19908   0.645161   0.516129
#
# [1058331 rows x 11 columns]

# %%
df['BHA-RPM'].mode()
# Out:
# 0   -2.053388
# dtype: float64

# %%
df.describe()
# Out:
#              MROAVG        LROAVG         ROMIN         ROMAX        ZRANGE  \
# count  1.058331e+06  1.058331e+06  1.058331e+06  1.058331e+06  1.058331e+06
# mean   1.106796e+01  9.129260e+01  1.751512e+02  1.897362e+02  9.723866e+00
# std    1.291374e+00  5.951358e+01  2.307183e+01  1.484001e+01  5.712944e+00
# min    0.000000e+00  0.000000e+00  0.000000e+00  2.300000e+01  3.000000e+00
# 25%    1.000000e+01  6.000000e+01  1.530000e+02  1.770000e+02  5.000000e+00
# 50%    1.200000e+01  6.600000e+01  1.920000e+02  1.990000e+02  7.000000e+00
# 75%    1.200000e+01  1.070000e+02  1.930000e+02  1.990000e+02  1.400000e+01
# max    1.500000e+01  2.550000e+02  2.140000e+02  2.550000e+02  1.340000e+02
#
#              YRANGE          TEMP             *       BHA-RPM          Z-Gs  \
# count  1.058331e+06  1.058331e+06  1.058331e+06  1.058331e+06  1.058331e+06
# mean   1.636343e+01  8.025222e+01  7.029937e-03  2.632569e+01  1.254692e+00
# std    1.376947e+01  3.926130e+01  6.744973e-01  4.072431e+01  7.371541e-01
# min    3.000000e+00  1.500000e+01  0.000000e+00 -1.192334e+02  3.870968e-01
# 25%    5.000000e+00  4.800000e+01  0.000000e+00 -2.737851e+00  6.451613e-01
# 50%    1.200000e+01  7.600000e+01  0.000000e+00 -1.779603e+00  9.032258e-01
# 75%    2.600000e+01  1.230000e+02  0.000000e+00  6.598220e+01  1.806452e+00
# max    1.390000e+02  1.510000e+02  1.280000e+02  4.182067e+02  1.729032e+01
#
#               XY-Gs
# count  1.058331e+06
# mean   2.111410e+00
# std    1.776706e+00
# min    3.870968e-01
# 25%    6.451613e-01
# 50%    1.548387e+00
# 75%    3.354839e+00
# max    1.793548e+01

# %%
i = pd.date_range('2018-04-09 10:00:00.5', periods=1058331     , freq='500L')
df['Datetime'] = i

# %%
#pd.set_option("display.max_rows", None, "display.max_columns", None)

# %%
df
# Out:
#        MROAVG  LROAVG  ROMIN  ROMAX  ZRANGE  YRANGE  TEMP  *   BHA-RPM  \
# 0          12      17    141    198     131     135    24  0  3.832991
# 1          12      64    193    198       4       5    24  0 -2.600958
# 2          12      68    193    199       4       4    24  0 -3.148528
# 3          12      71    193    198       5       5    24  0 -3.559206
# 4          12      63    193    199       5       5    24  0 -2.464066
# ...       ...     ...    ...    ...     ...     ...   ... ..       ...
# 19904      11     255    133    197     131     129    20  0  6.297057
# 19905      12      58    192    198       5       5    20  0 -1.779603
# 19906      12      58    192    198       6       4    20  0 -1.779603
# 19907      12      58    193    199       6       5    19  0 -1.779603
# 19908      12      57    192    198       5       4    20  0 -1.642710
#
#             Z-Gs      XY-Gs                Datetime
# 0      16.903226  17.419355 2018-04-09 10:00:00.500
# 1       0.516129   0.645161 2018-04-09 10:00:01.000
# 2       0.516129   0.516129 2018-04-09 10:00:01.500
# 3       0.645161   0.645161 2018-04-09 10:00:02.000
# 4       0.645161   0.645161 2018-04-09 10:00:02.500
# ...          ...        ...                     ...
# 19904  16.903226  16.645161 2018-04-15 12:59:23.500
# 19905   0.645161   0.645161 2018-04-15 12:59:24.000
# 19906   0.774194   0.516129 2018-04-15 12:59:24.500
# 19907   0.774194   0.645161 2018-04-15 12:59:25.000
# 19908   0.645161   0.516129 2018-04-15 12:59:25.500
#
# [1058331 rows x 12 columns]

# %%
#df2 = df.loc[df['Datetime'] > '2018-04-09 12:59:03', "BHA-RPM"]
#df_temp = df.loc[df['Datetime'] > '2018-04-09 12:59:03', "TEMP"]

# %%
#df_temp

# %% [markdown]
# # EDA (Exploratory Data Analysis)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(20,10))
sns.heatmap(df.corr(), annot=True)
plt.title('Correlation Matrix')
plt.show()

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15, 5))

# alpha parameter adjusts the point transparency. points with much more overlap will appear darker.
sns.scatterplot(x= df['Datetime'], y= df['BHA-RPM'], data=df, alpha=0.3, ax=axes[0])
axes[0].set_title('Datatime VS. BHA-RPM')

sns.scatterplot(x='Datetime', y='TEMP', data=df, alpha=0.3, ax=axes[1])
axes[1].set_title('Datetime VS. TEMP')

plt.show()

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(20, 10))

# alpha parameter adjusts the point transparency. points with much more overlap will appear darker.
sns.scatterplot(x= df['Datetime'], y= df['Z-Gs'], data=df, alpha=0.3, ax=axes[0])
axes[0].set_title('Datetime VS. Z-Gs')

sns.scatterplot(x='Datetime', y=df['XY-Gs'], data=df, alpha=0.3, ax=axes[1])
axes[1].set_title('Datetime VS. XY-Gs')

plt.show()

# %%
#df.drop(df.loc[df['Datetime'] < '2018-04-09 15:59:03', "BHA-RPM"].index, inplace = True)

# %%
#df.drop(df.loc[df['BHA-RPM']  > -420, 'BHA-RPM'].index, inplace = True)

# %%
df.drop(df.loc[df['BHA-RPM']  > 501, 'BHA-RPM'].index, inplace = True)
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(20, 10))

# alpha parameter adjusts the point transparency. points with much more overlap will appear darker.
sns.scatterplot(x= df['Datetime'], y= df['BHA-RPM'], data=df, alpha=0.3, ax=axes[0])
axes[0].set_title('Datetime VS. BHA-RPM')

sns.scatterplot(x='Datetime', y=df['TEMP'], data=df, alpha=0.3, ax=axes[1])
axes[1].set_title('Datetime VS. TEMP')

plt.show()

# %%
df.drop(df.loc[df['BHA-RPM']  < -250 , 'BHA-RPM'].index, inplace = True)

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(20, 10))

# alpha parameter adjusts the point transparency. points with much more overlap will appear darker.
sns.scatterplot(x= df['Datetime'], y= df['BHA-RPM'], data=df, alpha=0.3, ax=axes[0])
axes[0].set_title('Datetime VS. BHA-RPM')

sns.scatterplot(x='Datetime', y=df['TEMP'], data=df, alpha=0.3, ax=axes[1])
axes[1].set_title('Datetime VS. TEMP')

plt.show()

# %%
#df.drop(df[df['TEMP'] > 100 ].index, inplace = True)

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(20, 10))

# alpha parameter adjusts the point transparency. points with much more overlap will appear darker.
sns.scatterplot(x= df['Datetime'], y= df['BHA-RPM'], data=df, alpha=0.3, ax=axes[0])
axes[0].set_title('Datetime VS. BHA-RPM')

sns.scatterplot(x='Datetime', y=df['TEMP'], data=df, alpha=0.3, ax=axes[1])
axes[1].set_title('Datetime VS. TEMP')

plt.show()

# %% [markdown]
# # Shock and Vibration
# ### Drop the first hour or so of the remove the Noise

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(20, 10))

# alpha parameter adjusts the point transparency. points with much more overlap will appear darker.
sns.scatterplot(x= df['Datetime'], y= df['Z-Gs'], data=df, alpha=0.3, ax=axes[0])
axes[0].set_title('Datetime VS. Z-Gs')

sns.scatterplot(x='Datetime', y=df['XY-Gs'], data=df, alpha=0.3, ax=axes[1])
axes[1].set_title('Datetime VS. XY-Gs')

plt.show()

# %%
df.drop(df[df['Z-Gs'] > 21 ].index, inplace = True)

# %%
df.drop(df.loc[df['Datetime'] < '2018-04-09 15:59:03', "Z-Gs"].index, inplace = True)
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(20, 10))

# alpha parameter adjusts the point transparency. points with much more overlap will appear darker.
sns.scatterplot(x= df['Datetime'], y= df['Z-Gs'], data=df, alpha=0.3, ax=axes[0])
axes[0].set_title('Datetime VS. Z-Gs')

sns.scatterplot(x='Datetime', y=df['XY-Gs'], data=df, alpha=0.3, ax=axes[1])
axes[1].set_title('Datetime VS. XY-Gs')

plt.show()

# %%
df.drop(df.loc[df['BHA-RPM']  >425.694045 , 'BHA-RPM'].index, inplace = True)

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(20, 10))

# alpha parameter adjusts the point transparency. points with much more overlap will appear darker.
sns.scatterplot(x= df['Datetime'], y= df['BHA-RPM'], data=df, alpha=0.3, ax=axes[0])
axes[0].set_title('Datetime VS. BHA-RPM')

sns.scatterplot(x='Datetime', y=df['TEMP'], data=df, alpha=0.3, ax=axes[1])
axes[1].set_title('Datetime VS. TEMP')

plt.show()

# %%
df
# Out:
#          MROAVG  LROAVG  ROMIN  ROMAX  ZRANGE  YRANGE  TEMP  *   BHA-RPM  \
# 52941        12      64    193    199       5       4    29  0 -2.600958
# 52942        12      65    193    199       5       4    29  0 -2.737851
# 52943        12      65    193    199       5       4    29  0 -2.737851
# 52944        12      66    193    199       5       4    29  0 -2.874743
# 52945        12      62    193    199       5       4    29  0 -2.327173
# ...         ...     ...    ...    ...     ...     ...   ... ..       ...
# 1048507      12      64    192    199       5       4    38  0 -2.600958
# 1048508      12      62    192    199       4       4    38  0 -2.327173
# 1048509      12      59    193    199       5       5    38  0 -1.916496
# 1048510      12      61    192    199       5       4    38  0 -2.190281
# 1048511      12      62    193    199       5       5    38  0 -2.327173
#
#              Z-Gs     XY-Gs                Datetime
# 52941    0.645161  0.516129 2018-04-09 15:59:03.000
# 52942    0.645161  0.516129 2018-04-09 15:59:03.500
# 52943    0.645161  0.516129 2018-04-09 15:59:04.000
# 52944    0.645161  0.516129 2018-04-09 15:59:04.500
# 52945    0.645161  0.516129 2018-04-09 15:59:05.000
# ...           ...       ...                     ...
# 1048507  0.645161  0.516129 2018-04-15 10:15:05.000
# 1048508  0.516129  0.516129 2018-04-15 10:15:05.500
# 1048509  0.645161  0.645161 2018-04-15 10:15:06.000
# 1048510  0.645161  0.516129 2018-04-15 10:15:06.500
# 1048511  0.645161  0.645161 2018-04-15 10:15:07.000
#
# [995529 rows x 12 columns]

# %% [markdown]
# ### How many Z-Gs is over 12

# %%
Z_Gs_over_12 = (df['Z-Gs'].values > 12).sum()
Z_Gs_over_20 = (df['Z-Gs'].values > 20).sum()
Z_Gs_over_30 = (df['Z-Gs'].values > 30).sum()
Z_Gs_over_40 = (df['Z-Gs'].values > 40).sum()

print(Z_Gs_over_12)
print(Z_Gs_over_20)
print(Z_Gs_over_30)
print(Z_Gs_over_40)
# Out:
# 1
# 0
# 0
# 0

# %% [markdown]
# ### How many XY-Gs is over 12

# %%
XY_Gs_over_12 =(df['XY-Gs'].values > 12).sum()
XY_Gs_over_20 =(df['XY-Gs'].values > 20).sum()
XY_Gs_over_30 =(df['XY-Gs'].values > 30).sum()
XY_Gs_over_40 =(df['XY-Gs'].values > 40).sum()

print(XY_Gs_over_12)
print(XY_Gs_over_20)
print(XY_Gs_over_30)
print(XY_Gs_over_40)
# Out:
# 324
# 0
# 0
# 0

# %% [markdown]
# # BHA-RPM positive and negative values counts

# %% [markdown]
# ### BHA-RPM over 200

# %%
(df['BHA-RPM'].values > 200).sum()
# Out:
# 1124

# %% [markdown]
# ### BHA-RPM less 200 (include Negatives)

# %%
(df['BHA-RPM'].values <= 200).sum()
# Out:
# 994405

# %% [markdown]
# ### BHA-RPM less than Negative 10

# %%
RPM_less_than_Negative_10 = (df['BHA-RPM'].values <= -10).sum()
print('Number of RPM_less_than_Negative_10: ', RPM_less_than_Negative_10)
# Out:
# Number of RPM_less_than_Negative_10:  5534

# %% [markdown]
# ### BHA-RPM less than Negative 100

# %%
RPM_less_than_Negative_100 = (df['BHA-RPM'].values <= -100).sum()
print('Number of RPM_less_than_Negative_100: ', RPM_less_than_Negative_100)
# Out:
# Number of RPM_less_than_Negative_100:  2

# %%
RPM_over_200 =(df['BHA-RPM'].values > 200).sum()
RPM_over_300 =(df['BHA-RPM'].values > 300).sum()
RPM_over_400 =(df['BHA-RPM'].values > 400).sum()

# %%
print('Number of RPM_over_200:', RPM_over_200)
print('Number of RPM_over_300:', RPM_over_300)
print('Number of RPM_over_400:', RPM_over_400)
# Out:
# Number of RPM_over_200: 1124
# Number of RPM_over_300: 83
# Number of RPM_over_400: 5

# %%
# alpha parameter adjusts the point transparency. points with much more overlap will appear darker.
sns.scatterplot(x= df['Datetime'], y= df['BHA-RPM'], data=df, alpha=0.3)
axes[0].set_title('Datetime VS. BHA-RPM')
# Out:
# Text(0.5, 1.0, 'Datetime VS. BHA-RPM')

# %%
percent_of_RPM_over_200 = RPM_over_200/(df['BHA-RPM'].values < 200).sum()*100
print('Percent of percent_of_RPM_over_200: ', percent_of_RPM_over_200)
# Out:
# Percent of percent_of_RPM_over_200:  0.11303253003809316

# %% [markdown]
# # How many percent of BHA-RPM is more than 200

# %%
print(percent_of_RPM_over_200)
print(RPM_over_200)
# Out:
# 0.11303253003809316
# 1124

# %%
"""yerror = 
plt.errorbar( df['BHA-RPM'].index, df['BHA-RPM'], yerr=yerror, fmt='o')"""
# Out:
# "yerror = \nplt.errorbar( df['BHA-RPM'].index, df['BHA-RPM'], yerr=yerror, fmt='o')"

# %%
temp_mean = df["TEMP"].mean()
temp_max = df['TEMP'].max()
temp_min = df['TEMP'].min()
temp_std = df['TEMP'].std()

# %%
BHA_RPM_mean = df['BHA-RPM'].mean()
BHA_RPM_max = df['BHA-RPM'].max()
BHA_RPM_min = df['BHA-RPM'].min()
BHA_RPM_std = df['BHA-RPM'].std()

# %%
Z_Gs_mean = df['Z-Gs'].mean()
Z_Gs_max = df['Z-Gs'].max()
Z_Gs_min = df['Z-Gs'].min()
Z_Gs_std = df['Z-Gs'].std()

# %%
XY_Gs_mean = df['XY-Gs'].mean()
XY_Gs_max = df['XY-Gs'].max()
XY_Gs_min = df['XY-Gs'].min()
XY_Gs_std = df['XY-Gs'].std()

# %%
df.describe()
# Out:
#               MROAVG         LROAVG          ROMIN          ROMAX  \
# count  995529.000000  995529.000000  995529.000000  995529.000000
# mean       11.009188      92.947072     174.048361     189.151778
# std         1.309428      60.968195      23.352711      15.110004
# min         0.000000       0.000000       0.000000      23.000000
# 25%        10.000000      59.000000     152.000000     175.000000
# 50%        12.000000      66.000000     192.000000     199.000000
# 75%        12.000000     116.000000     192.000000     199.000000
# max        15.000000     255.000000     214.000000     255.000000
#
#               ZRANGE         YRANGE           TEMP         *        BHA-RPM  \
# count  995529.000000  995529.000000  995529.000000  995529.0  995529.000000
# mean       10.017340      17.078785      83.541211       0.0      28.158902
# std         5.746375      13.821003      38.100601       0.0      41.308818
# min         3.000000       3.000000      15.000000       0.0    -119.233402
# 25%         5.000000       5.000000      55.000000       0.0      -2.600958
# 50%         8.000000      13.000000      77.000000       0.0      -1.779603
# 75%        14.000000      26.000000     124.000000       0.0      68.720055
# max       131.000000     127.000000     129.000000       0.0     418.206708
#
#                 Z-Gs          XY-Gs
# count  995529.000000  995529.000000
# mean        1.292560       2.203714
# std         0.741468       1.783355
# min         0.387097       0.387097
# 25%         0.645161       0.645161
# 50%         1.032258       1.677419
# 75%         1.806452       3.354839
# max        16.903226      16.387097

# %%
df
# Out:
#          MROAVG  LROAVG  ROMIN  ROMAX  ZRANGE  YRANGE  TEMP  *   BHA-RPM  \
# 52941        12      64    193    199       5       4    29  0 -2.600958
# 52942        12      65    193    199       5       4    29  0 -2.737851
# 52943        12      65    193    199       5       4    29  0 -2.737851
# 52944        12      66    193    199       5       4    29  0 -2.874743
# 52945        12      62    193    199       5       4    29  0 -2.327173
# ...         ...     ...    ...    ...     ...     ...   ... ..       ...
# 1048507      12      64    192    199       5       4    38  0 -2.600958
# 1048508      12      62    192    199       4       4    38  0 -2.327173
# 1048509      12      59    193    199       5       5    38  0 -1.916496
# 1048510      12      61    192    199       5       4    38  0 -2.190281
# 1048511      12      62    193    199       5       5    38  0 -2.327173
#
#              Z-Gs     XY-Gs                Datetime
# 52941    0.645161  0.516129 2018-04-09 15:59:03.000
# 52942    0.645161  0.516129 2018-04-09 15:59:03.500
# 52943    0.645161  0.516129 2018-04-09 15:59:04.000
# 52944    0.645161  0.516129 2018-04-09 15:59:04.500
# 52945    0.645161  0.516129 2018-04-09 15:59:05.000
# ...           ...       ...                     ...
# 1048507  0.645161  0.516129 2018-04-15 10:15:05.000
# 1048508  0.516129  0.516129 2018-04-15 10:15:05.500
# 1048509  0.645161  0.645161 2018-04-15 10:15:06.000
# 1048510  0.645161  0.516129 2018-04-15 10:15:06.500
# 1048511  0.645161  0.645161 2018-04-15 10:15:07.000
#
# [995529 rows x 12 columns]

# %%
df.reset_index(drop = True, inplace = True)

# %%
df
# Out:
#         MROAVG  LROAVG  ROMIN  ROMAX  ZRANGE  YRANGE  TEMP  *   BHA-RPM  \
# 0           12      64    193    199       5       4    29  0 -2.600958
# 1           12      65    193    199       5       4    29  0 -2.737851
# 2           12      65    193    199       5       4    29  0 -2.737851
# 3           12      66    193    199       5       4    29  0 -2.874743
# 4           12      62    193    199       5       4    29  0 -2.327173
# ...        ...     ...    ...    ...     ...     ...   ... ..       ...
# 995524      12      64    192    199       5       4    38  0 -2.600958
# 995525      12      62    192    199       4       4    38  0 -2.327173
# 995526      12      59    193    199       5       5    38  0 -1.916496
# 995527      12      61    192    199       5       4    38  0 -2.190281
# 995528      12      62    193    199       5       5    38  0 -2.327173
#
#             Z-Gs     XY-Gs                Datetime
# 0       0.645161  0.516129 2018-04-09 15:59:03.000
# 1       0.645161  0.516129 2018-04-09 15:59:03.500
# 2       0.645161  0.516129 2018-04-09 15:59:04.000
# 3       0.645161  0.516129 2018-04-09 15:59:04.500
# 4       0.645161  0.516129 2018-04-09 15:59:05.000
# ...          ...       ...                     ...
# 995524  0.645161  0.516129 2018-04-15 10:15:05.000
# 995525  0.516129  0.516129 2018-04-15 10:15:05.500
# 995526  0.645161  0.645161 2018-04-15 10:15:06.000
# 995527  0.645161  0.516129 2018-04-15 10:15:06.500
# 995528  0.645161  0.645161 2018-04-15 10:15:07.000
#
# [995529 rows x 12 columns]

# %%
#df.to_excel(r'SN_0012.xlsx', index = False)

# %%
from csv import writer

def append_list_as_row(file_name, list_of_elem):
    # Open file in append mode
    with open(file_name, 'a+', newline='') as write_obj:
        # Create a writer object from csv module
        csv_writer = writer(write_obj)
        # Add contents of list as last row in the csv file
        csv_writer.writerow(list_of_elem)

# %%
# List of strings
row_contents = [Job_info, shrimp_number, BHA_RPM_mean, BHA_RPM_max, BHA_RPM_min, BHA_RPM_std, RPM_over_200, RPM_over_300, RPM_over_400, percent_of_RPM_over_200, RPM_less_than_Negative_10, RPM_less_than_Negative_100,
                temp_mean, temp_max, temp_std, 
                Z_Gs_mean, Z_Gs_max, Z_Gs_std, Z_Gs_over_12, Z_Gs_over_20, Z_Gs_over_30, Z_Gs_over_40, 
                XY_Gs_mean, XY_Gs_max, XY_Gs_std, XY_Gs_over_12, XY_Gs_over_20, XY_Gs_over_30, XY_Gs_over_40]
# Append a list as new line to an old csv file
append_list_as_row('SHRIMP Report.csv', row_contents)
