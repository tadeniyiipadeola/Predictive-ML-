# %% [markdown]
# ## 1. Introduction to Random Forest algorithm
#
#
# #### Random forest is a supervised learning algorithm. It has two variations – one is used for classification problems and other is used for regression problems. It is one of the most flexible and easy to use algorithm. It creates decision trees on the given data samples, gets prediction from each tree and selects the best solution by means of voting. It is also a pretty good indicator of feature importance.
#
# #### Random forest algorithm combines multiple decision-trees, resulting in a forest of trees, hence the name Random Forest. In the random forest classifier, the higher the number of trees in the forest results in higher accuracy.

# %% [markdown]
# ## 2. Random Forest algorithm intuition
# #### Table of Contents
#
# #### Random forest algorithm intuition can be divided into two stages.
#
# #### In the first stage, we randomly select “k” features out of total m features and build the random forest. In the first stage, we proceed as follows:-
#
# #### Randomly select k features from a total of m features where k < m.
# #### Among the k features, calculate the node d using the best split point.
# #### Split the node into daughter nodes using the best split.
# #### Repeat 1 to 3 steps until l number of nodes has been reached.
# #### Build forest by repeating steps 1 to 4 for n number of times to create n number of trees.
# #### In the second stage, we make predictions using the trained random forest algorithm.
#
# #### We take the test features and use the rules of each randomly created decision tree to predict the outcome and stores the predicted outcome.
# #### Then, we calculate the votes for each predicted target.
# #### Finally, we consider the high voted predicted target as the final prediction from the random forest algorithm.

# %% [markdown]
# ## 3. Advantages and disadvantages of Random Forest algorithm
# Table of Contents
#
# The advantages of Random forest algorithm are as follows:-
#
# #### Random forest algorithm can be used to solve both classification and regression problems.
# #### It is considered as very accurate and robust model because it uses large number of decision-trees to make predictions.
# #### Random forests takes the average of all the predictions made by the decision-trees, which cancels out the biases. So, it does not suffer from the overfitting problem.
# #### Random forest classifier can handle the missing values. There are two ways to handle the missing values. First is to use median values to replace continuous variables and second is to compute the proximity-weighted average of missing values.
# #### Random forest classifier can be used for feature selection. It means selecting the most important features out of the available features from the training dataset.
# The disadvantages of Random Forest algorithm are listed below:-
#
# #### The biggest disadvantage of random forests is its computational complexity. Random forests is very slow in making predictions because large number of decision-trees are used to make predictions. All the trees in the forest have to make a prediction for the same input and then perform voting on it. So, it is a time-consuming process.
# #### The model is difficult to interpret as compared to a decision-tree, where we can easily make a prediction as compared to a decision-tree

# %% [markdown]
# ## 4. Feature selection with Random Forests
# ##### Table of Contents
#
# #### Random forests algorithm can be used for feature selection process. This algorithm can be used to rank the importance of variables in a regression or classification problem.
#
# #### We measure the variable importance in a dataset by fitting the random forest algorithm to the data. During the fitting process, the out-of-bag error for each data point is recorded and averaged over the forest.
#
# #### The importance of the j-th feature was measured after training. The values of the j-th feature were permuted among the training data and the out-of-bag error was again computed on this perturbed dataset. The importance score for the j-th feature is computed by averaging the difference in out-of-bag error before and after the permutation over all trees. The score is normalized by the standard deviation of these differences.
#
# #### Features which produce large values for this score are ranked as more important than features which produce small values. Based on this score, we will choose the most important features and drop the least important ones for model building.

# %% [markdown]
# ## 5. Difference between Random Forests and Decision Trees ¶
# ### Table of Contents
#
# ### I will compare random forests with decision-trees. Some salient features of comparison are as follows:-
#
# #### Random forests is a set of multiple decision-trees.
#
# #### Decision-trees are computationally faster as compared to random forests.
#
# #### Deep decision-trees may suffer from overfitting. Random forest prevents overfitting by creating trees on random forests.
#
# #### Random forest is difficult to interpret. But, a decision-tree is easily interpretable and can be converted to rules

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from collections import Counter

# %%
from matplotlib import rcParams
rcParams['figure.figsize'] = 15, 5
sns.set_style('darkgrid')

# %% [markdown]
# ## Loading the Data

# %%
df = pd.read_excel(r'C:\Users\adeni\OneDrive - KLX Energy\MWD Summeries\MWD-summaries 2017-2020 .xlsx')

# %% [markdown]
# ## Sampling and Details

# %%
pd.set_option('display.max_columns', None)
df.head()
# Out:
#        JOB #            LOCATION             CUSTOMER  \
# 0  GC-200090  La Salle Co, Texas           Chesapeake
# 1  GC-200076     Karnes Co Texas           BPX Energy
# 2  GC-200104   McMullen Co Texas  SilverBow Resources
# 3  GC-200122   Live Oak Co Texas   Verdun Oil Company
# 4  GC-200001    DeWitt Co, Texas       ConocoPhillips
#
#                        WELL NAME                     MWD PERSONNEL  \
# 0            LARSON HC1 LAS A 1H              P.PEREZ / J. KOLANDA
# 1             Lonesome Dove #10H                    Payton / David
# 2     San Miguel Ranch EF B #25H             P. DeSoto / B Johnson
# 3              Red Baron Unit #1          Kyle Clark / Brent McKim
# 4  G Klein C D-Weisch A ULW C 1   J.J. Pena-Alfaro, Chris McDaniel
#
#                      DD PERSONNEL      RIG Kit Box Run #             Date in   \
# 0         C. JACKSON / G. HICKM0N  H&P 624      25     1  2020-01-15 00:00:00
# 1                Scottie / Jeremy  H&P 501      90     3  2020-01-16 00:00:00
# 2         D. Kingston / A. Vaughn  H&P 254      59     1  2020-01-23 00:00:00
# 3  TJ Arterberry / Mackey Belgard  H&P 420      80     2  2020-01-26 00:00:00
# 4      Justin Webb / Danny Bryant  H&P 256      63     2  2020-01-05 00:00:00
#
#              Date out   Time in   Time out  In hole hrs  Run Circ. Hrs.  \
# 0  2020-01-15 00:00:00  15:30:00  17:30:00          2.0             1.0
# 1  2020-01-17 00:00:00  12:00:00  18:00:00         30.0            20.5
# 2  2020-01-24 00:00:00  21:30:00  17:30:00         20.0            11.0
# 3  2020-01-30 00:00:00  09:45:00  11:30:00         97.8            82.0
# 4  2019-01-07 00:00:00  15:00:00  14:30:00         47.5            33.5
#
#    Depth In  Depth Out  Total Drilled    ROP          Bit MFG Bit size  \
# 0       109      230.0          121.0  121.0    ULTERRA/U6165    12.25
# 1     12115    14210.0         2095.0  102.0   Baker / DD406S      8.5
# 2        80     5595.0         5515.0  501.0          Ulterra    12.25
# 3     11804    19730.0         7926.0   97.0  Baker / DD506TS      8.5
# 4     11449    13081.0         1632.0   49.0            Baker     8.75
#
#        Jets              BHA BHA SIZE Motor Make Bend   GPM  RPM:   SPM:  \
# 0      6X18        STEERABLE        0        QES  1.83  600     0  186.0
# 1    6 x 22         CurveLat        7        QES     2  700    90  217.0
# 2     6-14s          Surface        8        QES  1.75  900    90  279.0
# 3  9 x 18's  Curve / Lateral        7        QES     2  700   105  238.0
# 4    6x22's        Steerable        7        QES     2  550    60  170.0
#
#    Pump Press  Temp in F  Temp out F  Mud # Total correction Mag Dec  Inc In  \
# 0         750        0.0         0.0    8.5             4.46    Grid     0.0
# 1        6000      228.0       275.0   12.1              3.1    Grid    43.7
# 2        2360        0.0       129.0    9.2             3.67    Grid     0.0
# 3        6651      246.0       317.0   12.6             3.52    Grid     1.0
# 4        3449      241.0       249.0   12.9             2.91    Grid    13.2
#
#    Inc Out  Azm In  Azm out Batt. 2  Interconnect     Elec. Interconnect.1  \
# 0      0.0     0.0      0.0     5377      NextGen  0337 XXT        NextGen
# 1     95.6   302.2    313.1     5434      NextGen      329K        NextGen
# 2      4.8     0.0    287.2     5515      NextGen   0595xxt        NextGen
# 3     93.3   260.7    320.1      682      NextGen     0177K        NextGen
# 4     85.3   309.7    119.9     5464      NextGen     2765K        NextGen
#
#   Batt. 1  Interconnect.2       Gamma Interconnect.3 Pulser Lower end  \
# 0      737        NextGen           0              0   6446        L2
# 1     5355        NextGen  L102 Titan        NextGen   4463       M77
# 2     5529        NextGen    1237 CBG        NextGen   2997       M90
# 3     3030        NextGen         681        NextGen   3122      GC-5
# 4      534        NextGen    683Deteq        NextGen   3183       M73
#
#   M/S Sleeve  M/S Sub Poppet  Orifice  Pulse Ampl Failures Failures.1     NPT  \
# 0        1ST      802  1.086     1.50        20.0      YES          1     2.5
# 1        3rd  650-753  1.122     1.35        57.0      YES          2  15 HRS
# 2        2ND      724  1.086     1.50       104.0      Yes          3       0
# 3      Run 1  650-129  1.125     1.35        42.0      Yes          4    27.5
# 4      1 Run  650-756  1.125     1.35        80.0      Yes          5      16
#
#              Comments                                   Failure Comments  \
# 0  POOH TO CHANGE MWD                      NO SURVEY DUE TO RATTY PULSES
# 1         MWD Failure                      DIP ANGLE BAD - MAGNETICS BAD
# 2  TD Surface @ 5595'                    Tool Flatlined After Surface TD
# 3         MWD Failure  Tool Flatlined during a Slide / Pressure increase
# 4      Change Out MWD   Tool QC readings on Grav & MagF out of tolerance
#
#    Unnamed: 59  Unnamed: 60  Unnamed: 61  Unnamed: 62  Unnamed: 63  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN          NaN
# 3          NaN          NaN          NaN          NaN          NaN
# 4          NaN          NaN          NaN          NaN          NaN
#
#    Unnamed: 64  Unnamed: 65  Unnamed: 66  Unnamed: 67  Unnamed: 68  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN          NaN
# 3          NaN          NaN          NaN          NaN          NaN
# 4          NaN          NaN          NaN          NaN          NaN
#
#    Unnamed: 69  Unnamed: 70  Unnamed: 71  Unnamed: 72  Unnamed: 73  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN          NaN
# 3          NaN          NaN          NaN          NaN          NaN
# 4          NaN          NaN          NaN          NaN          NaN
#
#    Unnamed: 74  Unnamed: 75  Unnamed: 76  Unnamed: 77  Unnamed: 78  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN          NaN
# 3          NaN          NaN          NaN          NaN          NaN
# 4          NaN          NaN          NaN          NaN          NaN
#
#    Unnamed: 79  Unnamed: 80  Unnamed: 81  Unnamed: 82  Unnamed: 83  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN          NaN
# 3          NaN          NaN          NaN          NaN          NaN
# 4          NaN          NaN          NaN          NaN          NaN
#
#    Unnamed: 84  Unnamed: 85  Unnamed: 86  Unnamed: 87  Unnamed: 88  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN          NaN
# 3          NaN          NaN          NaN          NaN          NaN
# 4          NaN          NaN          NaN          NaN          NaN
#
#    Unnamed: 89  Unnamed: 90  Unnamed: 91  Unnamed: 92  Unnamed: 93  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN          NaN
# 3          NaN          NaN          NaN          NaN          NaN
# 4          NaN          NaN          NaN          NaN          NaN
#
#    Unnamed: 94  Unnamed: 95  Unnamed: 96  Unnamed: 97  Unnamed: 98  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN          NaN
# 3          NaN          NaN          NaN          NaN          NaN
# 4          NaN          NaN          NaN          NaN          NaN
#
#    Unnamed: 99  Unnamed: 100
# 0          NaN           NaN
# 1          NaN           NaN
# 2          NaN           NaN
# 3          NaN           NaN
# 4          NaN           NaN

# %%
df.drop(["Unnamed: 59", "Unnamed: 60", "Unnamed: 61", "Unnamed: 62", "Unnamed: 63", "Unnamed: 64", "Unnamed: 65", "Unnamed: 66", "Unnamed: 67", "Unnamed: 68", "Unnamed: 69", "Unnamed: 70", "Unnamed: 71", "Unnamed: 72", "Unnamed: 73", "Unnamed: 74", "Unnamed: 75","Unnamed: 76","Unnamed: 77","Unnamed: 78","Unnamed: 79","Unnamed: 80","Unnamed: 81","Unnamed: 82","Unnamed: 83","Unnamed: 84","Unnamed: 85","Unnamed: 86","Unnamed: 87","Unnamed: 88","Unnamed: 89","Unnamed: 90","Unnamed: 91","Unnamed: 92","Unnamed: 93","Unnamed: 94","Unnamed: 95","Unnamed: 96","Unnamed: 97","Unnamed: 98","Unnamed: 99","Unnamed: 100"], axis=1, inplace = True)

# %%
pd.set_option('display.max_columns', None)
df.head()
# Out:
#        JOB #            LOCATION             CUSTOMER  \
# 0  GC-200090  La Salle Co, Texas           Chesapeake
# 1  GC-200076     Karnes Co Texas           BPX Energy
# 2  GC-200104   McMullen Co Texas  SilverBow Resources
# 3  GC-200122   Live Oak Co Texas   Verdun Oil Company
# 4  GC-200001    DeWitt Co, Texas       ConocoPhillips
#
#                        WELL NAME                     MWD PERSONNEL  \
# 0            LARSON HC1 LAS A 1H              P.PEREZ / J. KOLANDA
# 1             Lonesome Dove #10H                    Payton / David
# 2     San Miguel Ranch EF B #25H             P. DeSoto / B Johnson
# 3              Red Baron Unit #1          Kyle Clark / Brent McKim
# 4  G Klein C D-Weisch A ULW C 1   J.J. Pena-Alfaro, Chris McDaniel
#
#                      DD PERSONNEL      RIG Kit Box Run #             Date in   \
# 0         C. JACKSON / G. HICKM0N  H&P 624      25     1  2020-01-15 00:00:00
# 1                Scottie / Jeremy  H&P 501      90     3  2020-01-16 00:00:00
# 2         D. Kingston / A. Vaughn  H&P 254      59     1  2020-01-23 00:00:00
# 3  TJ Arterberry / Mackey Belgard  H&P 420      80     2  2020-01-26 00:00:00
# 4      Justin Webb / Danny Bryant  H&P 256      63     2  2020-01-05 00:00:00
#
#              Date out   Time in   Time out  In hole hrs  Run Circ. Hrs.  \
# 0  2020-01-15 00:00:00  15:30:00  17:30:00          2.0             1.0
# 1  2020-01-17 00:00:00  12:00:00  18:00:00         30.0            20.5
# 2  2020-01-24 00:00:00  21:30:00  17:30:00         20.0            11.0
# 3  2020-01-30 00:00:00  09:45:00  11:30:00         97.8            82.0
# 4  2019-01-07 00:00:00  15:00:00  14:30:00         47.5            33.5
#
#    Depth In  Depth Out  Total Drilled    ROP          Bit MFG Bit size  \
# 0       109      230.0          121.0  121.0    ULTERRA/U6165    12.25
# 1     12115    14210.0         2095.0  102.0   Baker / DD406S      8.5
# 2        80     5595.0         5515.0  501.0          Ulterra    12.25
# 3     11804    19730.0         7926.0   97.0  Baker / DD506TS      8.5
# 4     11449    13081.0         1632.0   49.0            Baker     8.75
#
#        Jets              BHA BHA SIZE Motor Make Bend   GPM  RPM:   SPM:  \
# 0      6X18        STEERABLE        0        QES  1.83  600     0  186.0
# 1    6 x 22         CurveLat        7        QES     2  700    90  217.0
# 2     6-14s          Surface        8        QES  1.75  900    90  279.0
# 3  9 x 18's  Curve / Lateral        7        QES     2  700   105  238.0
# 4    6x22's        Steerable        7        QES     2  550    60  170.0
#
#    Pump Press  Temp in F  Temp out F  Mud # Total correction Mag Dec  Inc In  \
# 0         750        0.0         0.0    8.5             4.46    Grid     0.0
# 1        6000      228.0       275.0   12.1              3.1    Grid    43.7
# 2        2360        0.0       129.0    9.2             3.67    Grid     0.0
# 3        6651      246.0       317.0   12.6             3.52    Grid     1.0
# 4        3449      241.0       249.0   12.9             2.91    Grid    13.2
#
#    Inc Out  Azm In  Azm out Batt. 2  Interconnect     Elec. Interconnect.1  \
# 0      0.0     0.0      0.0     5377      NextGen  0337 XXT        NextGen
# 1     95.6   302.2    313.1     5434      NextGen      329K        NextGen
# 2      4.8     0.0    287.2     5515      NextGen   0595xxt        NextGen
# 3     93.3   260.7    320.1      682      NextGen     0177K        NextGen
# 4     85.3   309.7    119.9     5464      NextGen     2765K        NextGen
#
#   Batt. 1  Interconnect.2       Gamma Interconnect.3 Pulser Lower end  \
# 0      737        NextGen           0              0   6446        L2
# 1     5355        NextGen  L102 Titan        NextGen   4463       M77
# 2     5529        NextGen    1237 CBG        NextGen   2997       M90
# 3     3030        NextGen         681        NextGen   3122      GC-5
# 4      534        NextGen    683Deteq        NextGen   3183       M73
#
#   M/S Sleeve  M/S Sub Poppet  Orifice  Pulse Ampl Failures Failures.1     NPT  \
# 0        1ST      802  1.086     1.50        20.0      YES          1     2.5
# 1        3rd  650-753  1.122     1.35        57.0      YES          2  15 HRS
# 2        2ND      724  1.086     1.50       104.0      Yes          3       0
# 3      Run 1  650-129  1.125     1.35        42.0      Yes          4    27.5
# 4      1 Run  650-756  1.125     1.35        80.0      Yes          5      16
#
#              Comments                                   Failure Comments
# 0  POOH TO CHANGE MWD                      NO SURVEY DUE TO RATTY PULSES
# 1         MWD Failure                      DIP ANGLE BAD - MAGNETICS BAD
# 2  TD Surface @ 5595'                    Tool Flatlined After Surface TD
# 3         MWD Failure  Tool Flatlined during a Slide / Pressure increase
# 4      Change Out MWD   Tool QC readings on Grav & MagF out of tolerance

# %%
df.corr()
# Out:
#                 In hole hrs  Run Circ. Hrs.  Depth In  Depth Out  \
# In hole hrs        1.000000        0.024255  0.042820   0.054783
# Run Circ. Hrs.     0.024255        1.000000  0.129618   0.509250
# Depth In           0.042820        0.129618  1.000000   0.844768
# Depth Out          0.054783        0.509250  0.844768   1.000000
# Total Drilled      0.026899        0.713107 -0.174438   0.379901
# ROP                0.018690       -0.061629 -0.351778  -0.166374
# GPM                0.011708        0.123154 -0.301100  -0.123284
# RPM:              -0.002041        0.326649 -0.032180   0.172979
# SPM:               0.002245        0.124691 -0.243976  -0.052319
# Pump Press         0.042758        0.493178  0.289037   0.547562
# Temp in F          0.013631        0.145977  0.729540   0.687850
# Temp out F         0.018055        0.226650  0.384610   0.500323
# Mud #              0.017604        0.008703  0.013355   0.013998
# Inc In             0.022580        0.188223  0.651364   0.577908
# Inc Out            0.032625        0.349839  0.682151   0.732979
# Azm In             0.002074        0.047928  0.121580   0.169947
# Azm out            0.004273       -0.007639  0.063486   0.088403
# Orifice           -0.008239       -0.032268 -0.317904  -0.265675
# Pulse Ampl         0.012166       -0.010098 -0.386888  -0.301380
#
#                 Total Drilled       ROP       GPM      RPM:      SPM:  \
# In hole hrs          0.026899  0.018690  0.011708 -0.002041  0.002245
# Run Circ. Hrs.       0.713107 -0.061629  0.123154  0.326649  0.124691
# Depth In            -0.174438 -0.351778 -0.301100 -0.032180 -0.243976
# Depth Out            0.379901 -0.166374 -0.123284  0.172979 -0.052319
# Total Drilled        1.000000  0.314685  0.293461  0.373981  0.323991
# ROP                  0.314685  1.000000  0.283763  0.199628  0.315463
# GPM                  0.293461  0.283763  1.000000  0.324287  0.939661
# RPM:                 0.373981  0.199628  0.324287  1.000000  0.310676
# SPM:                 0.323991  0.315463  0.939661  0.310676  1.000000
# Pump Press           0.507943  0.166818  0.375073  0.423642  0.417685
# Temp in F            0.004682 -0.209318 -0.133855  0.035444 -0.069795
# Temp out F           0.255824  0.005652  0.045291  0.133089  0.090961
# Mud #                0.002637 -0.005715  0.009441  0.011125  0.004317
# Inc In              -0.062721 -0.222851 -0.277681  0.054050 -0.236993
# Inc Out              0.167339 -0.181734 -0.223858  0.068507 -0.141826
# Azm In               0.102150 -0.007245 -0.006021  0.027209  0.029020
# Azm out              0.052985  0.023256 -0.044162  0.042874 -0.031515
# Orifice              0.060642  0.195195  0.258856  0.048529  0.201276
# Pulse Ampl           0.115937  0.177453  0.300262  0.078215  0.231421
#
#                 Pump Press  Temp in F  Temp out F     Mud #    Inc In  \
# In hole hrs       0.042758   0.013631    0.018055  0.017604  0.022580
# Run Circ. Hrs.    0.493178   0.145977    0.226650  0.008703  0.188223
# Depth In          0.289037   0.729540    0.384610  0.013355  0.651364
# Depth Out         0.547562   0.687850    0.500323  0.013998  0.577908
# Total Drilled     0.507943   0.004682    0.255824  0.002637 -0.062721
# ROP               0.166818  -0.209318    0.005652 -0.005715 -0.222851
# GPM               0.375073  -0.133855    0.045291  0.009441 -0.277681
# RPM:              0.423642   0.035444    0.133089  0.011125  0.054050
# SPM:              0.417685  -0.069795    0.090961  0.004317 -0.236993
# Pump Press        1.000000   0.328876    0.396958  0.011762  0.163734
# Temp in F         0.328876   1.000000    0.486885  0.011841  0.441339
# Temp out F        0.396958   0.486885    1.000000  0.002991  0.204620
# Mud #             0.011762   0.011841    0.002991  1.000000  0.028232
# Inc In            0.163734   0.441339    0.204620  0.028232  1.000000
# Inc Out           0.372562   0.528234    0.356725  0.028587  0.689351
# Azm In            0.112188   0.159603    0.076359 -0.040828  0.070215
# Azm out           0.060651   0.026415    0.066479  0.033747  0.069327
# Orifice          -0.042769  -0.159997   -0.049415 -0.001001 -0.312163
# Pulse Ampl       -0.060968  -0.276882   -0.142962 -0.015896 -0.235023
#
#                  Inc Out    Azm In   Azm out   Orifice  Pulse Ampl
# In hole hrs     0.032625  0.002074  0.004273 -0.008239    0.012166
# Run Circ. Hrs.  0.349839  0.047928 -0.007639 -0.032268   -0.010098
# Depth In        0.682151  0.121580  0.063486 -0.317904   -0.386888
# Depth Out       0.732979  0.169947  0.088403 -0.265675   -0.301380
# Total Drilled   0.167339  0.102150  0.052985  0.060642    0.115937
# ROP            -0.181734 -0.007245  0.023256  0.195195    0.177453
# GPM            -0.223858 -0.006021 -0.044162  0.258856    0.300262
# RPM:            0.068507  0.027209  0.042874  0.048529    0.078215
# SPM:           -0.141826  0.029020 -0.031515  0.201276    0.231421
# Pump Press      0.372562  0.112188  0.060651 -0.042769   -0.060968
# Temp in F       0.528234  0.159603  0.026415 -0.159997   -0.276882
# Temp out F      0.356725  0.076359  0.066479 -0.049415   -0.142962
# Mud #           0.028587 -0.040828  0.033747 -0.001001   -0.015896
# Inc In          0.689351  0.070215  0.069327 -0.312163   -0.235023
# Inc Out         1.000000  0.129824  0.136056 -0.338143   -0.242584
# Azm In          0.129824  1.000000  0.306788 -0.067923   -0.057927
# Azm out         0.136056  0.306788  1.000000 -0.051499   -0.041934
# Orifice        -0.338143 -0.067923 -0.051499  1.000000    0.118386
# Pulse Ampl     -0.242584 -0.057927 -0.041934  0.118386    1.000000

# %%
# df.info()

# %%
# pd.set_option('display.max_rows',df.shape[0]+1)
# df.isnull().sum()

# %%
df
# Out:
#           JOB #            LOCATION               CUSTOMER  \
# 0     GC-200090  La Salle Co, Texas             Chesapeake
# 1     GC-200076     Karnes Co Texas             BPX Energy
# 2     GC-200104   McMullen Co Texas    SilverBow Resources
# 3     GC-200122   Live Oak Co Texas     Verdun Oil Company
# 4     GC-200001    DeWitt Co, Texas         ConocoPhillips
# ...         ...                 ...                    ...
# 1276  MC-200838   Grady Co Oklahoma  Continental Resources
# 1277  MC-200838   Grady Co Oklahoma  Continental Resources
# 1278  MC-200838   Grady Co Oklahoma  Continental Resources
# 1279  MC-200838   Grady Co Oklahoma  Continental Resources
# 1280  MC-200838   Grady Co Oklahoma  Continental Resources
#
#                           WELL NAME                     MWD PERSONNEL  \
# 0               LARSON HC1 LAS A 1H              P.PEREZ / J. KOLANDA
# 1                Lonesome Dove #10H                    Payton / David
# 2        San Miguel Ranch EF B #25H             P. DeSoto / B Johnson
# 3                 Red Baron Unit #1          Kyle Clark / Brent McKim
# 4     G Klein C D-Weisch A ULW C 1   J.J. Pena-Alfaro, Chris McDaniel
# ...                             ...                               ...
# 1276                Goff 3-10-15XHW             B. Iguess / A. Culver
# 1277                Goff 3-10-15XHW             B. Iguess / A. Culver
# 1278                Goff 3-10-15XHW             B. Iguess / A. Culver
# 1279                Goff 3-10-15XHW             B. Iguess / A. Culver
# 1280                Goff 3-10-15XHW            J.Lindgren / A. Culver
#
#                         DD PERSONNEL            RIG Kit Box Run #  \
# 0            C. JACKSON / G. HICKM0N        H&P 624      25     1
# 1                   Scottie / Jeremy        H&P 501      90     3
# 2            D. Kingston / A. Vaughn        H&P 254      59     1
# 3     TJ Arterberry / Mackey Belgard        H&P 420      80     2
# 4         Justin Webb / Danny Bryant        H&P 256      63     2
# ...                              ...            ...     ...   ...
# 1276            Blaine  / John Davis  Patterson 590      19     2
# 1277            Blaine  / John Davis  Patterson 590      19     3
# 1278            Blaine  / John Davis  Patterson 590      19     4
# 1279            Blaine  / John Davis  Patterson 590      19     5
# 1280         John Davis / Russ Moore  Patterson 590      19     6
#
#                  Date in             Date out   Time in   Time out  \
# 0     2020-01-15 00:00:00  2020-01-15 00:00:00  15:30:00  17:30:00
# 1     2020-01-16 00:00:00  2020-01-17 00:00:00  12:00:00  18:00:00
# 2     2020-01-23 00:00:00  2020-01-24 00:00:00  21:30:00  17:30:00
# 3     2020-01-26 00:00:00  2020-01-30 00:00:00  09:45:00  11:30:00
# 4     2020-01-05 00:00:00  2019-01-07 00:00:00  15:00:00  14:30:00
# ...                   ...                  ...       ...       ...
# 1276  2020-11-29 00:00:00  2020-12-02 00:00:00  08:00:00  05:30:00
# 1277  2020-12-02 00:00:00  2020-12-04 00:00:00  08:00:00  07:30:00
# 1278  2020-12-04 00:00:00  2020-12-05 00:00:00  09:00:00  21:30:00
# 1279  2020-12-05 00:00:00  2020-12-06 00:00:00  22:15:00  22:00:00
# 1280  2021-01-11 00:00:00  2021-01-12 00:00:00  11:00:00  12:30:00
#
#       In hole hrs  Run Circ. Hrs.  Depth In  Depth Out  Total Drilled    ROP  \
# 0             2.0             1.0       109      230.0          121.0  121.0
# 1            30.0            20.5     12115    14210.0         2095.0  102.0
# 2            20.0            11.0        80     5595.0         5515.0  501.0
# 3            97.8            82.0     11804    19730.0         7926.0   97.0
# 4            47.5            33.5     11449    13081.0         1632.0   49.0
# ...           ...             ...       ...        ...            ...    ...
# 1276         69.5            57.5      6594     9726.0         3132.0   54.0
# 1277         47.5            38.0      9728    10736.0         1008.0   27.0
# 1278         36.5            15.5     10736    12369.0         1633.0  105.0
# 1279         23.8            12.0     12369    12876.0          507.0   42.0
# 1280         25.5            15.0     12876    13517.0          641.0   43.0
#
#               Bit MFG Bit size           Jets              BHA BHA SIZE  \
# 0       ULTERRA/U6165    12.25           6X18        STEERABLE        0
# 1      Baker / DD406S      8.5         6 x 22         CurveLat        7
# 2             Ulterra    12.25          6-14s          Surface        8
# 3     Baker / DD506TS      8.5       9 x 18's  Curve / Lateral        7
# 4               Baker     8.75         6x22's        Steerable        7
# ...               ...      ...            ...              ...      ...
# 1276  Ulterra / U613M    12.25      5x14,1x13      Tangent-RSS     9.65
# 1277  Ulterra / U613M    12.25      5x14,1x13      Tangent-RSS        9
# 1278      Varel V713P    12.25      4x12,3x13      Tangent-RSS        9
# 1279  Ulterra / U613M    12.25      5x14,1x13      Tangent-RSS     9.65
# 1280  Smith / XS616-E     8.75  3x11's/3x12's      Tangent-RSS     6.75
#
#      Motor Make     Bend   GPM  RPM:   SPM:  Pump Press  Temp in F  \
# 0           QES      1.83  600     0  186.0         750        0.0
# 1           QES         2  700    90  217.0        6000      228.0
# 2           QES      1.75  900    90  279.0        2360        0.0
# 3           QES         2  700   105  238.0        6651      246.0
# 4           QES         2  550    60  170.0        3449      241.0
# ...         ...       ...  ...   ...    ...         ...        ...
# 1276       Bico  Straight  900    40  256.0        4220      131.0
# 1277       Bico  Straight  855    75  243.0        4856      154.0
# 1278       Bico  Straight  855    37  243.0        4849      156.0
# 1279       Bico  Straight  834    51  237.0        4900      154.0
# 1280        QES  Straight  600    50  170.0        5500      163.0
#
#       Temp out F  Mud # Total correction Mag Dec  Inc In  Inc Out  Azm In  \
# 0            0.0   8.50             4.46    Grid     0.0      0.0     0.0
# 1          275.0  12.10              3.1    Grid    43.7     95.6   302.2
# 2          129.0   9.20             3.67    Grid     0.0      4.8     0.0
# 3          317.0  12.60             3.52    Grid     1.0     93.3   260.7
# 4          249.0  12.90             2.91    Grid    13.2     85.3   309.7
# ...          ...    ...              ...     ...     ...      ...     ...
# 1276       154.0   9.80             3.72    Grid     4.0      3.7   110.2
# 1277       156.0  10.05             3.72    Grid     3.7      4.4   103.5
# 1278       153.0   9.80             3.72    Grid     4.4      3.7   107.3
# 1279       163.0  10.00             3.72    Grid     3.7      3.9   103.5
# 1280       189.0  12.35             3.72    Grid     3.9      2.8    94.2
#
#       Azm out Batt. 2  Interconnect     Elec. Interconnect.1 Batt. 1   \
# 0         0.0     5377      NextGen  0337 XXT        NextGen      737
# 1       313.1     5434      NextGen      329K        NextGen     5355
# 2       287.2     5515      NextGen   0595xxt        NextGen     5529
# 3       320.1      682      NextGen     0177K        NextGen     3030
# 4       119.9     5464      NextGen     2765K        NextGen      534
# ...       ...      ...          ...       ...            ...      ...
# 1276    103.5      740      NextGen     24X5K        NextGen     5472
# 1277    107.3     5429      NextGen     0172K        NextGen     5284
# 1278     90.6     5429      NextGen     0172K        NextGen     5284
# 1279     94.2      740      NextGen     24X5K        NextGen     5472
# 1280    102.3       27      NextGen     4722K        NextGen      910
#
#      Interconnect.2       Gamma Interconnect.3 Pulser Lower end M/S Sleeve  \
# 0           NextGen           0              0   6446        L2        1ST
# 1           NextGen  L102 Titan        NextGen   4463       M77        3rd
# 2           NextGen    1237 CBG        NextGen   2997       M90        2ND
# 3           NextGen         681        NextGen   3122      GC-5      Run 1
# 4           NextGen    683Deteq        NextGen   3183       M73      1 Run
# ...             ...         ...            ...    ...       ...        ...
# 1276        NextGen    739Deteq        NextGen   5401       M57    2nd Run
# 1277        NextGen    779Deteq        NextGen   4671       M50    3rd Run
# 1278        NextGen    779Deteq        NextGen   4671       M50    3rd Run
# 1279        NextGen    739Deteq        NextGen   5401       M19    1st Run
# 1280        NextGen    762Deteq        NextGen   4464  5185/M76    1st Run
#
#       M/S Sub Poppet  Orifice  Pulse Ampl Failures Failures.1     NPT  \
# 0         802  1.086     1.50        20.0      YES          1     2.5
# 1     650-753  1.122     1.35        57.0      YES          2  15 HRS
# 2         724  1.086     1.50       104.0      Yes          3       0
# 3     650-129  1.125     1.35        42.0      Yes          4    27.5
# 4     650-756  1.125     1.35        80.0      Yes          5      16
# ...       ...    ...      ...         ...      ...        ...     ...
# 1276  800-807   1.04     1.50        30.0       No        115       0
# 1277  800-807  1.086     1.50        33.0       No        115       0
# 1278  800-807  1.086     1.50        24.0       No        115       0
# 1279  800-807   1.04     1.50        18.0       No        115       0
# 1280  650-748  1.125     1.40        24.0       No        115       0
#
#                  Comments                                   Failure Comments
# 0      POOH TO CHANGE MWD                      NO SURVEY DUE TO RATTY PULSES
# 1             MWD Failure                      DIP ANGLE BAD - MAGNETICS BAD
# 2      TD Surface @ 5595'                    Tool Flatlined After Surface TD
# 3             MWD Failure  Tool Flatlined during a Slide / Pressure increase
# 4          Change Out MWD   Tool QC readings on Grav & MagF out of tolerance
# ...                   ...                                                ...
# 1276        Bit and Motor                                Good Run For MWD!!!
# 1277  Bit and Motor / ROP                                Good Run For MWD!!!
# 1278            Bit / ROP                                Good Run For MWD!!!
# 1279  TD Vertical Section                                Good Run For MWD!!!
# 1280    POOH for slow ROP                                Good Run For MWD!!!
#
# [1281 rows x 59 columns]

# %% [markdown]
# ## Dropping Selected features

# %%
#df.drop(["Date out "], axis=1, inplace = True)

# %%
df
# Out:
#           JOB #            LOCATION               CUSTOMER  \
# 0     GC-200090  La Salle Co, Texas             Chesapeake
# 1     GC-200076     Karnes Co Texas             BPX Energy
# 2     GC-200104   McMullen Co Texas    SilverBow Resources
# 3     GC-200122   Live Oak Co Texas     Verdun Oil Company
# 4     GC-200001    DeWitt Co, Texas         ConocoPhillips
# ...         ...                 ...                    ...
# 1276  MC-200838   Grady Co Oklahoma  Continental Resources
# 1277  MC-200838   Grady Co Oklahoma  Continental Resources
# 1278  MC-200838   Grady Co Oklahoma  Continental Resources
# 1279  MC-200838   Grady Co Oklahoma  Continental Resources
# 1280  MC-200838   Grady Co Oklahoma  Continental Resources
#
#                           WELL NAME                     MWD PERSONNEL  \
# 0               LARSON HC1 LAS A 1H              P.PEREZ / J. KOLANDA
# 1                Lonesome Dove #10H                    Payton / David
# 2        San Miguel Ranch EF B #25H             P. DeSoto / B Johnson
# 3                 Red Baron Unit #1          Kyle Clark / Brent McKim
# 4     G Klein C D-Weisch A ULW C 1   J.J. Pena-Alfaro, Chris McDaniel
# ...                             ...                               ...
# 1276                Goff 3-10-15XHW             B. Iguess / A. Culver
# 1277                Goff 3-10-15XHW             B. Iguess / A. Culver
# 1278                Goff 3-10-15XHW             B. Iguess / A. Culver
# 1279                Goff 3-10-15XHW             B. Iguess / A. Culver
# 1280                Goff 3-10-15XHW            J.Lindgren / A. Culver
#
#                         DD PERSONNEL            RIG Kit Box Run #  \
# 0            C. JACKSON / G. HICKM0N        H&P 624      25     1
# 1                   Scottie / Jeremy        H&P 501      90     3
# 2            D. Kingston / A. Vaughn        H&P 254      59     1
# 3     TJ Arterberry / Mackey Belgard        H&P 420      80     2
# 4         Justin Webb / Danny Bryant        H&P 256      63     2
# ...                              ...            ...     ...   ...
# 1276            Blaine  / John Davis  Patterson 590      19     2
# 1277            Blaine  / John Davis  Patterson 590      19     3
# 1278            Blaine  / John Davis  Patterson 590      19     4
# 1279            Blaine  / John Davis  Patterson 590      19     5
# 1280         John Davis / Russ Moore  Patterson 590      19     6
#
#                  Date in             Date out   Time in   Time out  \
# 0     2020-01-15 00:00:00  2020-01-15 00:00:00  15:30:00  17:30:00
# 1     2020-01-16 00:00:00  2020-01-17 00:00:00  12:00:00  18:00:00
# 2     2020-01-23 00:00:00  2020-01-24 00:00:00  21:30:00  17:30:00
# 3     2020-01-26 00:00:00  2020-01-30 00:00:00  09:45:00  11:30:00
# 4     2020-01-05 00:00:00  2019-01-07 00:00:00  15:00:00  14:30:00
# ...                   ...                  ...       ...       ...
# 1276  2020-11-29 00:00:00  2020-12-02 00:00:00  08:00:00  05:30:00
# 1277  2020-12-02 00:00:00  2020-12-04 00:00:00  08:00:00  07:30:00
# 1278  2020-12-04 00:00:00  2020-12-05 00:00:00  09:00:00  21:30:00
# 1279  2020-12-05 00:00:00  2020-12-06 00:00:00  22:15:00  22:00:00
# 1280  2021-01-11 00:00:00  2021-01-12 00:00:00  11:00:00  12:30:00
#
#       In hole hrs  Run Circ. Hrs.  Depth In  Depth Out  Total Drilled    ROP  \
# 0             2.0             1.0       109      230.0          121.0  121.0
# 1            30.0            20.5     12115    14210.0         2095.0  102.0
# 2            20.0            11.0        80     5595.0         5515.0  501.0
# 3            97.8            82.0     11804    19730.0         7926.0   97.0
# 4            47.5            33.5     11449    13081.0         1632.0   49.0
# ...           ...             ...       ...        ...            ...    ...
# 1276         69.5            57.5      6594     9726.0         3132.0   54.0
# 1277         47.5            38.0      9728    10736.0         1008.0   27.0
# 1278         36.5            15.5     10736    12369.0         1633.0  105.0
# 1279         23.8            12.0     12369    12876.0          507.0   42.0
# 1280         25.5            15.0     12876    13517.0          641.0   43.0
#
#               Bit MFG Bit size           Jets              BHA BHA SIZE  \
# 0       ULTERRA/U6165    12.25           6X18        STEERABLE        0
# 1      Baker / DD406S      8.5         6 x 22         CurveLat        7
# 2             Ulterra    12.25          6-14s          Surface        8
# 3     Baker / DD506TS      8.5       9 x 18's  Curve / Lateral        7
# 4               Baker     8.75         6x22's        Steerable        7
# ...               ...      ...            ...              ...      ...
# 1276  Ulterra / U613M    12.25      5x14,1x13      Tangent-RSS     9.65
# 1277  Ulterra / U613M    12.25      5x14,1x13      Tangent-RSS        9
# 1278      Varel V713P    12.25      4x12,3x13      Tangent-RSS        9
# 1279  Ulterra / U613M    12.25      5x14,1x13      Tangent-RSS     9.65
# 1280  Smith / XS616-E     8.75  3x11's/3x12's      Tangent-RSS     6.75
#
#      Motor Make     Bend   GPM  RPM:   SPM:  Pump Press  Temp in F  \
# 0           QES      1.83  600     0  186.0         750        0.0
# 1           QES         2  700    90  217.0        6000      228.0
# 2           QES      1.75  900    90  279.0        2360        0.0
# 3           QES         2  700   105  238.0        6651      246.0
# 4           QES         2  550    60  170.0        3449      241.0
# ...         ...       ...  ...   ...    ...         ...        ...
# 1276       Bico  Straight  900    40  256.0        4220      131.0
# 1277       Bico  Straight  855    75  243.0        4856      154.0
# 1278       Bico  Straight  855    37  243.0        4849      156.0
# 1279       Bico  Straight  834    51  237.0        4900      154.0
# 1280        QES  Straight  600    50  170.0        5500      163.0
#
#       Temp out F  Mud # Total correction Mag Dec  Inc In  Inc Out  Azm In  \
# 0            0.0   8.50             4.46    Grid     0.0      0.0     0.0
# 1          275.0  12.10              3.1    Grid    43.7     95.6   302.2
# 2          129.0   9.20             3.67    Grid     0.0      4.8     0.0
# 3          317.0  12.60             3.52    Grid     1.0     93.3   260.7
# 4          249.0  12.90             2.91    Grid    13.2     85.3   309.7
# ...          ...    ...              ...     ...     ...      ...     ...
# 1276       154.0   9.80             3.72    Grid     4.0      3.7   110.2
# 1277       156.0  10.05             3.72    Grid     3.7      4.4   103.5
# 1278       153.0   9.80             3.72    Grid     4.4      3.7   107.3
# 1279       163.0  10.00             3.72    Grid     3.7      3.9   103.5
# 1280       189.0  12.35             3.72    Grid     3.9      2.8    94.2
#
#       Azm out Batt. 2  Interconnect     Elec. Interconnect.1 Batt. 1   \
# 0         0.0     5377      NextGen  0337 XXT        NextGen      737
# 1       313.1     5434      NextGen      329K        NextGen     5355
# 2       287.2     5515      NextGen   0595xxt        NextGen     5529
# 3       320.1      682      NextGen     0177K        NextGen     3030
# 4       119.9     5464      NextGen     2765K        NextGen      534
# ...       ...      ...          ...       ...            ...      ...
# 1276    103.5      740      NextGen     24X5K        NextGen     5472
# 1277    107.3     5429      NextGen     0172K        NextGen     5284
# 1278     90.6     5429      NextGen     0172K        NextGen     5284
# 1279     94.2      740      NextGen     24X5K        NextGen     5472
# 1280    102.3       27      NextGen     4722K        NextGen      910
#
#      Interconnect.2       Gamma Interconnect.3 Pulser Lower end M/S Sleeve  \
# 0           NextGen           0              0   6446        L2        1ST
# 1           NextGen  L102 Titan        NextGen   4463       M77        3rd
# 2           NextGen    1237 CBG        NextGen   2997       M90        2ND
# 3           NextGen         681        NextGen   3122      GC-5      Run 1
# 4           NextGen    683Deteq        NextGen   3183       M73      1 Run
# ...             ...         ...            ...    ...       ...        ...
# 1276        NextGen    739Deteq        NextGen   5401       M57    2nd Run
# 1277        NextGen    779Deteq        NextGen   4671       M50    3rd Run
# 1278        NextGen    779Deteq        NextGen   4671       M50    3rd Run
# 1279        NextGen    739Deteq        NextGen   5401       M19    1st Run
# 1280        NextGen    762Deteq        NextGen   4464  5185/M76    1st Run
#
#       M/S Sub Poppet  Orifice  Pulse Ampl Failures Failures.1     NPT  \
# 0         802  1.086     1.50        20.0      YES          1     2.5
# 1     650-753  1.122     1.35        57.0      YES          2  15 HRS
# 2         724  1.086     1.50       104.0      Yes          3       0
# 3     650-129  1.125     1.35        42.0      Yes          4    27.5
# 4     650-756  1.125     1.35        80.0      Yes          5      16
# ...       ...    ...      ...         ...      ...        ...     ...
# 1276  800-807   1.04     1.50        30.0       No        115       0
# 1277  800-807  1.086     1.50        33.0       No        115       0
# 1278  800-807  1.086     1.50        24.0       No        115       0
# 1279  800-807   1.04     1.50        18.0       No        115       0
# 1280  650-748  1.125     1.40        24.0       No        115       0
#
#                  Comments                                   Failure Comments
# 0      POOH TO CHANGE MWD                      NO SURVEY DUE TO RATTY PULSES
# 1             MWD Failure                      DIP ANGLE BAD - MAGNETICS BAD
# 2      TD Surface @ 5595'                    Tool Flatlined After Surface TD
# 3             MWD Failure  Tool Flatlined during a Slide / Pressure increase
# 4          Change Out MWD   Tool QC readings on Grav & MagF out of tolerance
# ...                   ...                                                ...
# 1276        Bit and Motor                                Good Run For MWD!!!
# 1277  Bit and Motor / ROP                                Good Run For MWD!!!
# 1278            Bit / ROP                                Good Run For MWD!!!
# 1279  TD Vertical Section                                Good Run For MWD!!!
# 1280    POOH for slow ROP                                Good Run For MWD!!!
#
# [1281 rows x 59 columns]

# %%
# pd.set_option('display.max_rows',df.shape[0]+1)
# df.isnull().sum()

# %% [markdown]
# ## Feature correction by mapping

# %%
failure_mapping = {'Yes':1, 'YES':1, 'yes':1, 'Yes ':1, 'no':0, 'No':0, 'NO':0, 'N0':0}
# Effected_mapping = {'Yes':1, 'YES':1, 'yes':1, 'Yes ':1, 'no':0, 'No':0, 'NO':0, 'N0':0}

# %%
df['Failures'] = df['Failures'].map(failure_mapping)
# df['Client Effected'] = df['Client Effected'].map(Effected_mapping)

# %%
pd.set_option('display.max_columns', None)
df.head()
# Out:
#        JOB #            LOCATION             CUSTOMER  \
# 0  GC-200090  La Salle Co, Texas           Chesapeake
# 1  GC-200076     Karnes Co Texas           BPX Energy
# 2  GC-200104   McMullen Co Texas  SilverBow Resources
# 3  GC-200122   Live Oak Co Texas   Verdun Oil Company
# 4  GC-200001    DeWitt Co, Texas       ConocoPhillips
#
#                        WELL NAME                     MWD PERSONNEL  \
# 0            LARSON HC1 LAS A 1H              P.PEREZ / J. KOLANDA
# 1             Lonesome Dove #10H                    Payton / David
# 2     San Miguel Ranch EF B #25H             P. DeSoto / B Johnson
# 3              Red Baron Unit #1          Kyle Clark / Brent McKim
# 4  G Klein C D-Weisch A ULW C 1   J.J. Pena-Alfaro, Chris McDaniel
#
#                      DD PERSONNEL      RIG Kit Box Run #             Date in   \
# 0         C. JACKSON / G. HICKM0N  H&P 624      25     1  2020-01-15 00:00:00
# 1                Scottie / Jeremy  H&P 501      90     3  2020-01-16 00:00:00
# 2         D. Kingston / A. Vaughn  H&P 254      59     1  2020-01-23 00:00:00
# 3  TJ Arterberry / Mackey Belgard  H&P 420      80     2  2020-01-26 00:00:00
# 4      Justin Webb / Danny Bryant  H&P 256      63     2  2020-01-05 00:00:00
#
#              Date out   Time in   Time out  In hole hrs  Run Circ. Hrs.  \
# 0  2020-01-15 00:00:00  15:30:00  17:30:00          2.0             1.0
# 1  2020-01-17 00:00:00  12:00:00  18:00:00         30.0            20.5
# 2  2020-01-24 00:00:00  21:30:00  17:30:00         20.0            11.0
# 3  2020-01-30 00:00:00  09:45:00  11:30:00         97.8            82.0
# 4  2019-01-07 00:00:00  15:00:00  14:30:00         47.5            33.5
#
#    Depth In  Depth Out  Total Drilled    ROP          Bit MFG Bit size  \
# 0       109      230.0          121.0  121.0    ULTERRA/U6165    12.25
# 1     12115    14210.0         2095.0  102.0   Baker / DD406S      8.5
# 2        80     5595.0         5515.0  501.0          Ulterra    12.25
# 3     11804    19730.0         7926.0   97.0  Baker / DD506TS      8.5
# 4     11449    13081.0         1632.0   49.0            Baker     8.75
#
#        Jets              BHA BHA SIZE Motor Make Bend   GPM  RPM:   SPM:  \
# 0      6X18        STEERABLE        0        QES  1.83  600     0  186.0
# 1    6 x 22         CurveLat        7        QES     2  700    90  217.0
# 2     6-14s          Surface        8        QES  1.75  900    90  279.0
# 3  9 x 18's  Curve / Lateral        7        QES     2  700   105  238.0
# 4    6x22's        Steerable        7        QES     2  550    60  170.0
#
#    Pump Press  Temp in F  Temp out F  Mud # Total correction Mag Dec  Inc In  \
# 0         750        0.0         0.0    8.5             4.46    Grid     0.0
# 1        6000      228.0       275.0   12.1              3.1    Grid    43.7
# 2        2360        0.0       129.0    9.2             3.67    Grid     0.0
# 3        6651      246.0       317.0   12.6             3.52    Grid     1.0
# 4        3449      241.0       249.0   12.9             2.91    Grid    13.2
#
#    Inc Out  Azm In  Azm out Batt. 2  Interconnect     Elec. Interconnect.1  \
# 0      0.0     0.0      0.0     5377      NextGen  0337 XXT        NextGen
# 1     95.6   302.2    313.1     5434      NextGen      329K        NextGen
# 2      4.8     0.0    287.2     5515      NextGen   0595xxt        NextGen
# 3     93.3   260.7    320.1      682      NextGen     0177K        NextGen
# 4     85.3   309.7    119.9     5464      NextGen     2765K        NextGen
#
#   Batt. 1  Interconnect.2       Gamma Interconnect.3 Pulser Lower end  \
# 0      737        NextGen           0              0   6446        L2
# 1     5355        NextGen  L102 Titan        NextGen   4463       M77
# 2     5529        NextGen    1237 CBG        NextGen   2997       M90
# 3     3030        NextGen         681        NextGen   3122      GC-5
# 4      534        NextGen    683Deteq        NextGen   3183       M73
#
#   M/S Sleeve  M/S Sub Poppet  Orifice  Pulse Ampl  Failures Failures.1  \
# 0        1ST      802  1.086     1.50        20.0       1.0          1
# 1        3rd  650-753  1.122     1.35        57.0       1.0          2
# 2        2ND      724  1.086     1.50       104.0       1.0          3
# 3      Run 1  650-129  1.125     1.35        42.0       1.0          4
# 4      1 Run  650-756  1.125     1.35        80.0       1.0          5
#
#       NPT            Comments  \
# 0     2.5  POOH TO CHANGE MWD
# 1  15 HRS         MWD Failure
# 2       0  TD Surface @ 5595'
# 3    27.5         MWD Failure
# 4      16      Change Out MWD
#
#                                     Failure Comments
# 0                      NO SURVEY DUE TO RATTY PULSES
# 1                      DIP ANGLE BAD - MAGNETICS BAD
# 2                    Tool Flatlined After Surface TD
# 3  Tool Flatlined during a Slide / Pressure increase
# 4   Tool QC readings on Grav & MagF out of tolerance

# %%
df.corr()
# Out:
#                 In hole hrs  Run Circ. Hrs.  Depth In  Depth Out  \
# In hole hrs        1.000000        0.024255  0.042820   0.054783
# Run Circ. Hrs.     0.024255        1.000000  0.129618   0.509250
# Depth In           0.042820        0.129618  1.000000   0.844768
# Depth Out          0.054783        0.509250  0.844768   1.000000
# Total Drilled      0.026899        0.713107 -0.174438   0.379901
# ROP                0.018690       -0.061629 -0.351778  -0.166374
# GPM                0.011708        0.123154 -0.301100  -0.123284
# RPM:              -0.002041        0.326649 -0.032180   0.172979
# SPM:               0.002245        0.124691 -0.243976  -0.052319
# Pump Press         0.042758        0.493178  0.289037   0.547562
# Temp in F          0.013631        0.145977  0.729540   0.687850
# Temp out F         0.018055        0.226650  0.384610   0.500323
# Mud #              0.017604        0.008703  0.013355   0.013998
# Inc In             0.022580        0.188223  0.651364   0.577908
# Inc Out            0.032625        0.349839  0.682151   0.732979
# Azm In             0.002074        0.047928  0.121580   0.169947
# Azm out            0.004273       -0.007639  0.063486   0.088403
# Orifice           -0.008239       -0.032268 -0.317904  -0.265675
# Pulse Ampl         0.012166       -0.010098 -0.386888  -0.301380
# Failures          -0.027542       -0.277409  0.064946  -0.066370
#
#                 Total Drilled       ROP       GPM      RPM:      SPM:  \
# In hole hrs          0.026899  0.018690  0.011708 -0.002041  0.002245
# Run Circ. Hrs.       0.713107 -0.061629  0.123154  0.326649  0.124691
# Depth In            -0.174438 -0.351778 -0.301100 -0.032180 -0.243976
# Depth Out            0.379901 -0.166374 -0.123284  0.172979 -0.052319
# Total Drilled        1.000000  0.314685  0.293461  0.373981  0.323991
# ROP                  0.314685  1.000000  0.283763  0.199628  0.315463
# GPM                  0.293461  0.283763  1.000000  0.324287  0.939661
# RPM:                 0.373981  0.199628  0.324287  1.000000  0.310676
# SPM:                 0.323991  0.315463  0.939661  0.310676  1.000000
# Pump Press           0.507943  0.166818  0.375073  0.423642  0.417685
# Temp in F            0.004682 -0.209318 -0.133855  0.035444 -0.069795
# Temp out F           0.255824  0.005652  0.045291  0.133089  0.090961
# Mud #                0.002637 -0.005715  0.009441  0.011125  0.004317
# Inc In              -0.062721 -0.222851 -0.277681  0.054050 -0.236993
# Inc Out              0.167339 -0.181734 -0.223858  0.068507 -0.141826
# Azm In               0.102150 -0.007245 -0.006021  0.027209  0.029020
# Azm out              0.052985  0.023256 -0.044162  0.042874 -0.031515
# Orifice              0.060642  0.195195  0.258856  0.048529  0.201276
# Pulse Ampl           0.115937  0.177453  0.300262  0.078215  0.231421
# Failures            -0.234642 -0.047814 -0.141530 -0.154404 -0.124220
#
#                 Pump Press  Temp in F  Temp out F     Mud #    Inc In  \
# In hole hrs       0.042758   0.013631    0.018055  0.017604  0.022580
# Run Circ. Hrs.    0.493178   0.145977    0.226650  0.008703  0.188223
# Depth In          0.289037   0.729540    0.384610  0.013355  0.651364
# Depth Out         0.547562   0.687850    0.500323  0.013998  0.577908
# Total Drilled     0.507943   0.004682    0.255824  0.002637 -0.062721
# ROP               0.166818  -0.209318    0.005652 -0.005715 -0.222851
# GPM               0.375073  -0.133855    0.045291  0.009441 -0.277681
# RPM:              0.423642   0.035444    0.133089  0.011125  0.054050
# SPM:              0.417685  -0.069795    0.090961  0.004317 -0.236993
# Pump Press        1.000000   0.328876    0.396958  0.011762  0.163734
# Temp in F         0.328876   1.000000    0.486885  0.011841  0.441339
# Temp out F        0.396958   0.486885    1.000000  0.002991  0.204620
# Mud #             0.011762   0.011841    0.002991  1.000000  0.028232
# Inc In            0.163734   0.441339    0.204620  0.028232  1.000000
# Inc Out           0.372562   0.528234    0.356725  0.028587  0.689351
# Azm In            0.112188   0.159603    0.076359 -0.040828  0.070215
# Azm out           0.060651   0.026415    0.066479  0.033747  0.069327
# Orifice          -0.042769  -0.159997   -0.049415 -0.001001 -0.312163
# Pulse Ampl       -0.060968  -0.276882   -0.142962 -0.015896 -0.235023
# Failures         -0.195246   0.091917    0.025259  0.015936  0.071839
#
#                  Inc Out    Azm In   Azm out   Orifice  Pulse Ampl  Failures
# In hole hrs     0.032625  0.002074  0.004273 -0.008239    0.012166 -0.027542
# Run Circ. Hrs.  0.349839  0.047928 -0.007639 -0.032268   -0.010098 -0.277409
# Depth In        0.682151  0.121580  0.063486 -0.317904   -0.386888  0.064946
# Depth Out       0.732979  0.169947  0.088403 -0.265675   -0.301380 -0.066370
# Total Drilled   0.167339  0.102150  0.052985  0.060642    0.115937 -0.234642
# ROP            -0.181734 -0.007245  0.023256  0.195195    0.177453 -0.047814
# GPM            -0.223858 -0.006021 -0.044162  0.258856    0.300262 -0.141530
# RPM:            0.068507  0.027209  0.042874  0.048529    0.078215 -0.154404
# SPM:           -0.141826  0.029020 -0.031515  0.201276    0.231421 -0.124220
# Pump Press      0.372562  0.112188  0.060651 -0.042769   -0.060968 -0.195246
# Temp in F       0.528234  0.159603  0.026415 -0.159997   -0.276882  0.091917
# Temp out F      0.356725  0.076359  0.066479 -0.049415   -0.142962  0.025259
# Mud #           0.028587 -0.040828  0.033747 -0.001001   -0.015896  0.015936
# Inc In          0.689351  0.070215  0.069327 -0.312163   -0.235023  0.071839
# Inc Out         1.000000  0.129824  0.136056 -0.338143   -0.242584  0.043122
# Azm In          0.129824  1.000000  0.306788 -0.067923   -0.057927 -0.015605
# Azm out         0.136056  0.306788  1.000000 -0.051499   -0.041934 -0.072055
# Orifice        -0.338143 -0.067923 -0.051499  1.000000    0.118386 -0.042015
# Pulse Ampl     -0.242584 -0.057927 -0.041934  0.118386    1.000000 -0.083637
# Failures        0.043122 -0.015605 -0.072055 -0.042015   -0.083637  1.000000

# %% [markdown]
# ## Checking features for null values

# %%
c=0
is_null = []
for i in df.columns:
    if df[i].isnull().sum()>0:
        is_null.append(i)
        print(i,df[i].isnull().sum())
        c = c+1
print("Number of coumns containing null values are:", c)
# Out:
# DD PERSONNEL 2
# Time in  1
# Time out 1
# In hole hrs 3
# Total Drilled 1
# ROP 26
# Bit MFG 1
# Jets 2
# BHA SIZE 2
# Motor Make 5
# Bend  2
# SPM: 30
# Total correction 1
# Mag Dec 1
# Inc In 4
# Inc Out 6
# Azm In 4
# Azm out 6
# Interconnect 4
# Elec. 1
# Interconnect.1 4
# Interconnect.2 4
# Gamma 7
# Interconnect.3 17
# Pulser 1
# Lower end 1
# M/S Sleeve 41
# M/S Sub 18
# Poppet 1
# Orifice 1
# Pulse Ampl 46
# Failures 18
# Failures.1 1
# NPT 1
# Comments 2
# Failure Comments 7
# Number of coumns containing null values are: 36

# %% [markdown]
# ## classify into object and floats

# %%
obj = []
for i in df.columns:
    if df[i].dtypes == 'object':
        obj.append(i)
# obj

# %%
# for i in obj:
#     sns.countplot(x=i, data=df)
#     plt.show()

# %% [markdown]
# ## Barplot for Failure and counts

# %%
    sns.countplot(x=df["Failures"])
    plt.show()

# %%
df['Failures'].value_counts()
# Out:
# 1.0    646
# 0.0    617
# Name: Failures, dtype: int64

# %%
df['Temp in F'].value_counts()
# Out:
# 0.0      130
# 131.0     35
# 138.0     29
# 145.0     26
# 120.0     26
#         ...
# 132.0      1
# 261.0      1
# 119.0      1
# 257.0      1
# 213.8      1
# Name: Temp in F, Length: 204, dtype: int64

# %% [markdown]
# ## EDA, Exploratory Data

# %%
# failure_mapping = {'NA':0, 'na':0,}

# %%
# df['Temp in F'] = df['Temp in F'].map(failure_mapping)

# %%
# df['Temp in F']=df['Temp in F'].astype(int, errors='ignore') 
# df['Temp out F']=df['Temp out F'].astype(int, errors='ignore')

# %%
from sklearn import preprocessing
le=preprocessing.LabelEncoder()

df['CUSTOMER']=le.fit_transform(df['CUSTOMER'])
df['LOCATION']=le.fit_transform(df['LOCATION'])
df['RIG']=le.fit_transform(df['RIG'])
# df['Temp in F']=le.fit_transform(df['Temp in F'])
# df['Temp out F']=le.fit_transform(df['Temp out F']).astype(int, errors='str')

df.head()
# Out:
#        JOB #  LOCATION  CUSTOMER                      WELL NAME  \
# 0  GC-200090       100        30            LARSON HC1 LAS A 1H
# 1  GC-200076        85        10             Lonesome Dove #10H
# 2  GC-200104       131       137     San Miguel Ranch EF B #25H
# 3  GC-200122       114       148              Red Baron Unit #1
# 4  GC-200001        26        40  G Klein C D-Weisch A ULW C 1
#
#                       MWD PERSONNEL                    DD PERSONNEL  RIG  \
# 0              P.PEREZ / J. KOLANDA         C. JACKSON / G. HICKM0N   65
# 1                    Payton / David                Scottie / Jeremy   55
# 2             P. DeSoto / B Johnson         D. Kingston / A. Vaughn   35
# 3          Kyle Clark / Brent McKim  TJ Arterberry / Mackey Belgard   41
# 4  J.J. Pena-Alfaro, Chris McDaniel      Justin Webb / Danny Bryant   36
#
#   Kit Box Run #             Date in             Date out   Time in   Time out  \
# 0      25     1  2020-01-15 00:00:00  2020-01-15 00:00:00  15:30:00  17:30:00
# 1      90     3  2020-01-16 00:00:00  2020-01-17 00:00:00  12:00:00  18:00:00
# 2      59     1  2020-01-23 00:00:00  2020-01-24 00:00:00  21:30:00  17:30:00
# 3      80     2  2020-01-26 00:00:00  2020-01-30 00:00:00  09:45:00  11:30:00
# 4      63     2  2020-01-05 00:00:00  2019-01-07 00:00:00  15:00:00  14:30:00
#
#    In hole hrs  Run Circ. Hrs.  Depth In  Depth Out  Total Drilled    ROP  \
# 0          2.0             1.0       109      230.0          121.0  121.0
# 1         30.0            20.5     12115    14210.0         2095.0  102.0
# 2         20.0            11.0        80     5595.0         5515.0  501.0
# 3         97.8            82.0     11804    19730.0         7926.0   97.0
# 4         47.5            33.5     11449    13081.0         1632.0   49.0
#
#            Bit MFG Bit size      Jets              BHA BHA SIZE Motor Make  \
# 0    ULTERRA/U6165    12.25      6X18        STEERABLE        0        QES
# 1   Baker / DD406S      8.5    6 x 22         CurveLat        7        QES
# 2          Ulterra    12.25     6-14s          Surface        8        QES
# 3  Baker / DD506TS      8.5  9 x 18's  Curve / Lateral        7        QES
# 4            Baker     8.75    6x22's        Steerable        7        QES
#
#   Bend   GPM  RPM:   SPM:  Pump Press  Temp in F  Temp out F  Mud #  \
# 0  1.83  600     0  186.0         750        0.0         0.0    8.5
# 1     2  700    90  217.0        6000      228.0       275.0   12.1
# 2  1.75  900    90  279.0        2360        0.0       129.0    9.2
# 3     2  700   105  238.0        6651      246.0       317.0   12.6
# 4     2  550    60  170.0        3449      241.0       249.0   12.9
#
#   Total correction Mag Dec  Inc In  Inc Out  Azm In  Azm out Batt. 2   \
# 0             4.46    Grid     0.0      0.0     0.0      0.0     5377
# 1              3.1    Grid    43.7     95.6   302.2    313.1     5434
# 2             3.67    Grid     0.0      4.8     0.0    287.2     5515
# 3             3.52    Grid     1.0     93.3   260.7    320.1      682
# 4             2.91    Grid    13.2     85.3   309.7    119.9     5464
#
#   Interconnect     Elec. Interconnect.1 Batt. 1  Interconnect.2       Gamma  \
# 0      NextGen  0337 XXT        NextGen      737        NextGen           0
# 1      NextGen      329K        NextGen     5355        NextGen  L102 Titan
# 2      NextGen   0595xxt        NextGen     5529        NextGen    1237 CBG
# 3      NextGen     0177K        NextGen     3030        NextGen         681
# 4      NextGen     2765K        NextGen      534        NextGen    683Deteq
#
#   Interconnect.3 Pulser Lower end M/S Sleeve  M/S Sub Poppet  Orifice  \
# 0              0   6446        L2        1ST      802  1.086     1.50
# 1        NextGen   4463       M77        3rd  650-753  1.122     1.35
# 2        NextGen   2997       M90        2ND      724  1.086     1.50
# 3        NextGen   3122      GC-5      Run 1  650-129  1.125     1.35
# 4        NextGen   3183       M73      1 Run  650-756  1.125     1.35
#
#    Pulse Ampl  Failures Failures.1     NPT            Comments  \
# 0        20.0       1.0          1     2.5  POOH TO CHANGE MWD
# 1        57.0       1.0          2  15 HRS         MWD Failure
# 2       104.0       1.0          3       0  TD Surface @ 5595'
# 3        42.0       1.0          4    27.5         MWD Failure
# 4        80.0       1.0          5      16      Change Out MWD
#
#                                     Failure Comments
# 0                      NO SURVEY DUE TO RATTY PULSES
# 1                      DIP ANGLE BAD - MAGNETICS BAD
# 2                    Tool Flatlined After Surface TD
# 3  Tool Flatlined during a Slide / Pressure increase
# 4   Tool QC readings on Grav & MagF out of tolerance

# %%
# plt.figure(figsize=(6,8))
# x =df.drop(obj, axis =1)
# print(x.columns)
# for i in x.columns:
#     sns.scatterplot(x="Failures", y=i, data=x, color = 'Red')
#     plt.show()

# %%
# x=df.drop (obj,axis=1)
# for i in x.columns:
#     sns.violinplot(x=i, data =x, color = 'yellowgreen')
#     plt.xlabel(i)
#     plt.show()

# %%
# df.loc[131, "BRT Hours"] = np.nan
# df.loc[131, "BRT Hours"] = df['BRT Hours'].mean()

# df.loc[359, "NPT"] = 1.5

# %%
# pd.set_option('display.max_rows',df.shape[0]+1)
# df.isnull().sum()

# %% [markdown]
# ## classifying catergorical data from Numerical Data

# %%
df_num = df.select_dtypes(include=[np.number])
df_obj = df.select_dtypes(exclude=[np.number])

# %%
df_obj
# Out:
#           JOB #                      WELL NAME  \
# 0     GC-200090            LARSON HC1 LAS A 1H
# 1     GC-200076             Lonesome Dove #10H
# 2     GC-200104     San Miguel Ranch EF B #25H
# 3     GC-200122              Red Baron Unit #1
# 4     GC-200001  G Klein C D-Weisch A ULW C 1
# ...         ...                            ...
# 1276  MC-200838                Goff 3-10-15XHW
# 1277  MC-200838                Goff 3-10-15XHW
# 1278  MC-200838                Goff 3-10-15XHW
# 1279  MC-200838                Goff 3-10-15XHW
# 1280  MC-200838                Goff 3-10-15XHW
#
#                          MWD PERSONNEL                    DD PERSONNEL  \
# 0                 P.PEREZ / J. KOLANDA         C. JACKSON / G. HICKM0N
# 1                       Payton / David                Scottie / Jeremy
# 2                P. DeSoto / B Johnson         D. Kingston / A. Vaughn
# 3             Kyle Clark / Brent McKim  TJ Arterberry / Mackey Belgard
# 4     J.J. Pena-Alfaro, Chris McDaniel      Justin Webb / Danny Bryant
# ...                                ...                             ...
# 1276             B. Iguess / A. Culver            Blaine  / John Davis
# 1277             B. Iguess / A. Culver            Blaine  / John Davis
# 1278             B. Iguess / A. Culver            Blaine  / John Davis
# 1279             B. Iguess / A. Culver            Blaine  / John Davis
# 1280            J.Lindgren / A. Culver         John Davis / Russ Moore
#
#      Kit Box Run #             Date in             Date out   Time in   \
# 0         25     1  2020-01-15 00:00:00  2020-01-15 00:00:00  15:30:00
# 1         90     3  2020-01-16 00:00:00  2020-01-17 00:00:00  12:00:00
# 2         59     1  2020-01-23 00:00:00  2020-01-24 00:00:00  21:30:00
# 3         80     2  2020-01-26 00:00:00  2020-01-30 00:00:00  09:45:00
# 4         63     2  2020-01-05 00:00:00  2019-01-07 00:00:00  15:00:00
# ...      ...   ...                  ...                  ...       ...
# 1276      19     2  2020-11-29 00:00:00  2020-12-02 00:00:00  08:00:00
# 1277      19     3  2020-12-02 00:00:00  2020-12-04 00:00:00  08:00:00
# 1278      19     4  2020-12-04 00:00:00  2020-12-05 00:00:00  09:00:00
# 1279      19     5  2020-12-05 00:00:00  2020-12-06 00:00:00  22:15:00
# 1280      19     6  2021-01-11 00:00:00  2021-01-12 00:00:00  11:00:00
#
#       Time out          Bit MFG Bit size           Jets              BHA  \
# 0     17:30:00    ULTERRA/U6165    12.25           6X18        STEERABLE
# 1     18:00:00   Baker / DD406S      8.5         6 x 22         CurveLat
# 2     17:30:00          Ulterra    12.25          6-14s          Surface
# 3     11:30:00  Baker / DD506TS      8.5       9 x 18's  Curve / Lateral
# 4     14:30:00            Baker     8.75         6x22's        Steerable
# ...        ...              ...      ...            ...              ...
# 1276  05:30:00  Ulterra / U613M    12.25      5x14,1x13      Tangent-RSS
# 1277  07:30:00  Ulterra / U613M    12.25      5x14,1x13      Tangent-RSS
# 1278  21:30:00      Varel V713P    12.25      4x12,3x13      Tangent-RSS
# 1279  22:00:00  Ulterra / U613M    12.25      5x14,1x13      Tangent-RSS
# 1280  12:30:00  Smith / XS616-E     8.75  3x11's/3x12's      Tangent-RSS
#
#      BHA SIZE Motor Make     Bend  Total correction Mag Dec Batt. 2   \
# 0           0        QES      1.83             4.46    Grid     5377
# 1           7        QES         2              3.1    Grid     5434
# 2           8        QES      1.75             3.67    Grid     5515
# 3           7        QES         2             3.52    Grid      682
# 4           7        QES         2             2.91    Grid     5464
# ...       ...        ...       ...              ...     ...      ...
# 1276     9.65       Bico  Straight             3.72    Grid      740
# 1277        9       Bico  Straight             3.72    Grid     5429
# 1278        9       Bico  Straight             3.72    Grid     5429
# 1279     9.65       Bico  Straight             3.72    Grid      740
# 1280     6.75        QES  Straight             3.72    Grid       27
#
#      Interconnect     Elec. Interconnect.1 Batt. 1  Interconnect.2  \
# 0         NextGen  0337 XXT        NextGen      737        NextGen
# 1         NextGen      329K        NextGen     5355        NextGen
# 2         NextGen   0595xxt        NextGen     5529        NextGen
# 3         NextGen     0177K        NextGen     3030        NextGen
# 4         NextGen     2765K        NextGen      534        NextGen
# ...           ...       ...            ...      ...            ...
# 1276      NextGen     24X5K        NextGen     5472        NextGen
# 1277      NextGen     0172K        NextGen     5284        NextGen
# 1278      NextGen     0172K        NextGen     5284        NextGen
# 1279      NextGen     24X5K        NextGen     5472        NextGen
# 1280      NextGen     4722K        NextGen      910        NextGen
#
#            Gamma Interconnect.3 Pulser Lower end M/S Sleeve  M/S Sub Poppet  \
# 0              0              0   6446        L2        1ST      802  1.086
# 1     L102 Titan        NextGen   4463       M77        3rd  650-753  1.122
# 2       1237 CBG        NextGen   2997       M90        2ND      724  1.086
# 3            681        NextGen   3122      GC-5      Run 1  650-129  1.125
# 4       683Deteq        NextGen   3183       M73      1 Run  650-756  1.125
# ...          ...            ...    ...       ...        ...      ...    ...
# 1276    739Deteq        NextGen   5401       M57    2nd Run  800-807   1.04
# 1277    779Deteq        NextGen   4671       M50    3rd Run  800-807  1.086
# 1278    779Deteq        NextGen   4671       M50    3rd Run  800-807  1.086
# 1279    739Deteq        NextGen   5401       M19    1st Run  800-807   1.04
# 1280    762Deteq        NextGen   4464  5185/M76    1st Run  650-748  1.125
#
#      Failures.1     NPT             Comments  \
# 0             1     2.5   POOH TO CHANGE MWD
# 1             2  15 HRS          MWD Failure
# 2             3       0   TD Surface @ 5595'
# 3             4    27.5          MWD Failure
# 4             5      16       Change Out MWD
# ...         ...     ...                  ...
# 1276        115       0        Bit and Motor
# 1277        115       0  Bit and Motor / ROP
# 1278        115       0            Bit / ROP
# 1279        115       0  TD Vertical Section
# 1280        115       0    POOH for slow ROP
#
#                                        Failure Comments
# 0                         NO SURVEY DUE TO RATTY PULSES
# 1                         DIP ANGLE BAD - MAGNETICS BAD
# 2                       Tool Flatlined After Surface TD
# 3     Tool Flatlined during a Slide / Pressure increase
# 4      Tool QC readings on Grav & MagF out of tolerance
# ...                                                 ...
# 1276                                Good Run For MWD!!!
# 1277                                Good Run For MWD!!!
# 1278                                Good Run For MWD!!!
# 1279                                Good Run For MWD!!!
# 1280                                Good Run For MWD!!!
#
# [1281 rows x 36 columns]

# %%
df_num
# Out:
#       LOCATION  CUSTOMER  RIG  In hole hrs  Run Circ. Hrs.  Depth In  \
# 0          100        30   65          2.0             1.0       109
# 1           85        10   55         30.0            20.5     12115
# 2          131       137   35         20.0            11.0        80
# 3          114       148   41         97.8            82.0     11804
# 4           26        40   36         47.5            33.5     11449
# ...        ...       ...  ...          ...             ...       ...
# 1276        70        42  145         69.5            57.5      6594
# 1277        70        42  145         47.5            38.0      9728
# 1278        70        42  145         36.5            15.5     10736
# 1279        70        42  145         23.8            12.0     12369
# 1280        70        42  145         25.5            15.0     12876
#
#       Depth Out  Total Drilled    ROP  GPM  RPM:   SPM:  Pump Press  \
# 0         230.0          121.0  121.0  600     0  186.0         750
# 1       14210.0         2095.0  102.0  700    90  217.0        6000
# 2        5595.0         5515.0  501.0  900    90  279.0        2360
# 3       19730.0         7926.0   97.0  700   105  238.0        6651
# 4       13081.0         1632.0   49.0  550    60  170.0        3449
# ...         ...            ...    ...  ...   ...    ...         ...
# 1276     9726.0         3132.0   54.0  900    40  256.0        4220
# 1277    10736.0         1008.0   27.0  855    75  243.0        4856
# 1278    12369.0         1633.0  105.0  855    37  243.0        4849
# 1279    12876.0          507.0   42.0  834    51  237.0        4900
# 1280    13517.0          641.0   43.0  600    50  170.0        5500
#
#       Temp in F  Temp out F  Mud #  Inc In  Inc Out  Azm In  Azm out  Orifice  \
# 0           0.0         0.0   8.50     0.0      0.0     0.0      0.0     1.50
# 1         228.0       275.0  12.10    43.7     95.6   302.2    313.1     1.35
# 2           0.0       129.0   9.20     0.0      4.8     0.0    287.2     1.50
# 3         246.0       317.0  12.60     1.0     93.3   260.7    320.1     1.35
# 4         241.0       249.0  12.90    13.2     85.3   309.7    119.9     1.35
# ...         ...         ...    ...     ...      ...     ...      ...      ...
# 1276      131.0       154.0   9.80     4.0      3.7   110.2    103.5     1.50
# 1277      154.0       156.0  10.05     3.7      4.4   103.5    107.3     1.50
# 1278      156.0       153.0   9.80     4.4      3.7   107.3     90.6     1.50
# 1279      154.0       163.0  10.00     3.7      3.9   103.5     94.2     1.50
# 1280      163.0       189.0  12.35     3.9      2.8    94.2    102.3     1.40
#
#       Pulse Ampl  Failures
# 0           20.0       1.0
# 1           57.0       1.0
# 2          104.0       1.0
# 3           42.0       1.0
# 4           80.0       1.0
# ...          ...       ...
# 1276        30.0       0.0
# 1277        33.0       0.0
# 1278        24.0       0.0
# 1279        18.0       0.0
# 1280        24.0       0.0
#
# [1281 rows x 23 columns]

# %%
# pd.set_option('display.max_rows',df.shape[0]+1)
# df.isnull().sum()

# %%
def outliers(df, n, features):
    global outlier_indices
    outlier_indices = []
    for col in features:
        
        #1st quartile
        Q1 = np.percentile(df[col], 25)
        
        #3rd quartile
        Q3 = np.percentile(df[col], 75)
        
        #inter quartile range
        IQR = Q3 - Q1
        
        #identify index of outlier rows
        outlierlist = df[(df[col] < (Q1 - (1.5 * IQR))) | (df[col] > (Q3 + (1.5 * IQR)))].index
        
        outlier_indices.extend(outlierlist)
    outlier_indices = Counter(outlier_indices)
    multipleoutliers = list(k for k,v in outlier_indices.items() if v > n)
        
    return multipleoutliers
#detect outliers from Age, SibSp, Fare and Parch
finaloutliers = outliers(df_num, 2, df_num.columns)

# %% [markdown]
# ##  replacing Null values with mean values

# %%
for i in is_null:
    if df[i].dtype == "int64" or df[i].dtype == "float64":
        if i in outlier_indices:
            df[i]. fillna(df[i].median(), inplace =True)
        else:
            df[i].fillna(df[i].mean(), inplace=True)
    elif df[i].dtype == "object":
        df[i].fillna(df[i].mode()[0], inplace =True)

# %%
df_num = df.select_dtypes(include=[np.number])
df_obj = df.select_dtypes(exclude=[np.number])

# %%
df_obj
# Out:
#           JOB #                      WELL NAME  \
# 0     GC-200090            LARSON HC1 LAS A 1H
# 1     GC-200076             Lonesome Dove #10H
# 2     GC-200104     San Miguel Ranch EF B #25H
# 3     GC-200122              Red Baron Unit #1
# 4     GC-200001  G Klein C D-Weisch A ULW C 1
# ...         ...                            ...
# 1276  MC-200838                Goff 3-10-15XHW
# 1277  MC-200838                Goff 3-10-15XHW
# 1278  MC-200838                Goff 3-10-15XHW
# 1279  MC-200838                Goff 3-10-15XHW
# 1280  MC-200838                Goff 3-10-15XHW
#
#                          MWD PERSONNEL                    DD PERSONNEL  \
# 0                 P.PEREZ / J. KOLANDA         C. JACKSON / G. HICKM0N
# 1                       Payton / David                Scottie / Jeremy
# 2                P. DeSoto / B Johnson         D. Kingston / A. Vaughn
# 3             Kyle Clark / Brent McKim  TJ Arterberry / Mackey Belgard
# 4     J.J. Pena-Alfaro, Chris McDaniel      Justin Webb / Danny Bryant
# ...                                ...                             ...
# 1276             B. Iguess / A. Culver            Blaine  / John Davis
# 1277             B. Iguess / A. Culver            Blaine  / John Davis
# 1278             B. Iguess / A. Culver            Blaine  / John Davis
# 1279             B. Iguess / A. Culver            Blaine  / John Davis
# 1280            J.Lindgren / A. Culver         John Davis / Russ Moore
#
#      Kit Box Run #             Date in             Date out   Time in   \
# 0         25     1  2020-01-15 00:00:00  2020-01-15 00:00:00  15:30:00
# 1         90     3  2020-01-16 00:00:00  2020-01-17 00:00:00  12:00:00
# 2         59     1  2020-01-23 00:00:00  2020-01-24 00:00:00  21:30:00
# 3         80     2  2020-01-26 00:00:00  2020-01-30 00:00:00  09:45:00
# 4         63     2  2020-01-05 00:00:00  2019-01-07 00:00:00  15:00:00
# ...      ...   ...                  ...                  ...       ...
# 1276      19     2  2020-11-29 00:00:00  2020-12-02 00:00:00  08:00:00
# 1277      19     3  2020-12-02 00:00:00  2020-12-04 00:00:00  08:00:00
# 1278      19     4  2020-12-04 00:00:00  2020-12-05 00:00:00  09:00:00
# 1279      19     5  2020-12-05 00:00:00  2020-12-06 00:00:00  22:15:00
# 1280      19     6  2021-01-11 00:00:00  2021-01-12 00:00:00  11:00:00
#
#       Time out          Bit MFG Bit size           Jets              BHA  \
# 0     17:30:00    ULTERRA/U6165    12.25           6X18        STEERABLE
# 1     18:00:00   Baker / DD406S      8.5         6 x 22         CurveLat
# 2     17:30:00          Ulterra    12.25          6-14s          Surface
# 3     11:30:00  Baker / DD506TS      8.5       9 x 18's  Curve / Lateral
# 4     14:30:00            Baker     8.75         6x22's        Steerable
# ...        ...              ...      ...            ...              ...
# 1276  05:30:00  Ulterra / U613M    12.25      5x14,1x13      Tangent-RSS
# 1277  07:30:00  Ulterra / U613M    12.25      5x14,1x13      Tangent-RSS
# 1278  21:30:00      Varel V713P    12.25      4x12,3x13      Tangent-RSS
# 1279  22:00:00  Ulterra / U613M    12.25      5x14,1x13      Tangent-RSS
# 1280  12:30:00  Smith / XS616-E     8.75  3x11's/3x12's      Tangent-RSS
#
#      BHA SIZE Motor Make     Bend  Total correction Mag Dec Batt. 2   \
# 0           0        QES      1.83             4.46    Grid     5377
# 1           7        QES         2              3.1    Grid     5434
# 2           8        QES      1.75             3.67    Grid     5515
# 3           7        QES         2             3.52    Grid      682
# 4           7        QES         2             2.91    Grid     5464
# ...       ...        ...       ...              ...     ...      ...
# 1276     9.65       Bico  Straight             3.72    Grid      740
# 1277        9       Bico  Straight             3.72    Grid     5429
# 1278        9       Bico  Straight             3.72    Grid     5429
# 1279     9.65       Bico  Straight             3.72    Grid      740
# 1280     6.75        QES  Straight             3.72    Grid       27
#
#      Interconnect     Elec. Interconnect.1 Batt. 1  Interconnect.2  \
# 0         NextGen  0337 XXT        NextGen      737        NextGen
# 1         NextGen      329K        NextGen     5355        NextGen
# 2         NextGen   0595xxt        NextGen     5529        NextGen
# 3         NextGen     0177K        NextGen     3030        NextGen
# 4         NextGen     2765K        NextGen      534        NextGen
# ...           ...       ...            ...      ...            ...
# 1276      NextGen     24X5K        NextGen     5472        NextGen
# 1277      NextGen     0172K        NextGen     5284        NextGen
# 1278      NextGen     0172K        NextGen     5284        NextGen
# 1279      NextGen     24X5K        NextGen     5472        NextGen
# 1280      NextGen     4722K        NextGen      910        NextGen
#
#            Gamma Interconnect.3 Pulser Lower end M/S Sleeve  M/S Sub Poppet  \
# 0              0              0   6446        L2        1ST      802  1.086
# 1     L102 Titan        NextGen   4463       M77        3rd  650-753  1.122
# 2       1237 CBG        NextGen   2997       M90        2ND      724  1.086
# 3            681        NextGen   3122      GC-5      Run 1  650-129  1.125
# 4       683Deteq        NextGen   3183       M73      1 Run  650-756  1.125
# ...          ...            ...    ...       ...        ...      ...    ...
# 1276    739Deteq        NextGen   5401       M57    2nd Run  800-807   1.04
# 1277    779Deteq        NextGen   4671       M50    3rd Run  800-807  1.086
# 1278    779Deteq        NextGen   4671       M50    3rd Run  800-807  1.086
# 1279    739Deteq        NextGen   5401       M19    1st Run  800-807   1.04
# 1280    762Deteq        NextGen   4464  5185/M76    1st Run  650-748  1.125
#
#      Failures.1     NPT             Comments  \
# 0             1     2.5   POOH TO CHANGE MWD
# 1             2  15 HRS          MWD Failure
# 2             3       0   TD Surface @ 5595'
# 3             4    27.5          MWD Failure
# 4             5      16       Change Out MWD
# ...         ...     ...                  ...
# 1276        115       0        Bit and Motor
# 1277        115       0  Bit and Motor / ROP
# 1278        115       0            Bit / ROP
# 1279        115       0  TD Vertical Section
# 1280        115       0    POOH for slow ROP
#
#                                        Failure Comments
# 0                         NO SURVEY DUE TO RATTY PULSES
# 1                         DIP ANGLE BAD - MAGNETICS BAD
# 2                       Tool Flatlined After Surface TD
# 3     Tool Flatlined during a Slide / Pressure increase
# 4      Tool QC readings on Grav & MagF out of tolerance
# ...                                                 ...
# 1276                                Good Run For MWD!!!
# 1277                                Good Run For MWD!!!
# 1278                                Good Run For MWD!!!
# 1279                                Good Run For MWD!!!
# 1280                                Good Run For MWD!!!
#
# [1281 rows x 36 columns]

# %%
df_num
# Out:
#       LOCATION  CUSTOMER  RIG  In hole hrs  Run Circ. Hrs.  Depth In  \
# 0          100        30   65          2.0             1.0       109
# 1           85        10   55         30.0            20.5     12115
# 2          131       137   35         20.0            11.0        80
# 3          114       148   41         97.8            82.0     11804
# 4           26        40   36         47.5            33.5     11449
# ...        ...       ...  ...          ...             ...       ...
# 1276        70        42  145         69.5            57.5      6594
# 1277        70        42  145         47.5            38.0      9728
# 1278        70        42  145         36.5            15.5     10736
# 1279        70        42  145         23.8            12.0     12369
# 1280        70        42  145         25.5            15.0     12876
#
#       Depth Out  Total Drilled    ROP  GPM  RPM:   SPM:  Pump Press  \
# 0         230.0          121.0  121.0  600     0  186.0         750
# 1       14210.0         2095.0  102.0  700    90  217.0        6000
# 2        5595.0         5515.0  501.0  900    90  279.0        2360
# 3       19730.0         7926.0   97.0  700   105  238.0        6651
# 4       13081.0         1632.0   49.0  550    60  170.0        3449
# ...         ...            ...    ...  ...   ...    ...         ...
# 1276     9726.0         3132.0   54.0  900    40  256.0        4220
# 1277    10736.0         1008.0   27.0  855    75  243.0        4856
# 1278    12369.0         1633.0  105.0  855    37  243.0        4849
# 1279    12876.0          507.0   42.0  834    51  237.0        4900
# 1280    13517.0          641.0   43.0  600    50  170.0        5500
#
#       Temp in F  Temp out F  Mud #  Inc In  Inc Out  Azm In  Azm out  Orifice  \
# 0           0.0         0.0   8.50     0.0      0.0     0.0      0.0     1.50
# 1         228.0       275.0  12.10    43.7     95.6   302.2    313.1     1.35
# 2           0.0       129.0   9.20     0.0      4.8     0.0    287.2     1.50
# 3         246.0       317.0  12.60     1.0     93.3   260.7    320.1     1.35
# 4         241.0       249.0  12.90    13.2     85.3   309.7    119.9     1.35
# ...         ...         ...    ...     ...      ...     ...      ...      ...
# 1276      131.0       154.0   9.80     4.0      3.7   110.2    103.5     1.50
# 1277      154.0       156.0  10.05     3.7      4.4   103.5    107.3     1.50
# 1278      156.0       153.0   9.80     4.4      3.7   107.3     90.6     1.50
# 1279      154.0       163.0  10.00     3.7      3.9   103.5     94.2     1.50
# 1280      163.0       189.0  12.35     3.9      2.8    94.2    102.3     1.40
#
#       Pulse Ampl  Failures
# 0           20.0       1.0
# 1           57.0       1.0
# 2          104.0       1.0
# 3           42.0       1.0
# 4           80.0       1.0
# ...          ...       ...
# 1276        30.0       0.0
# 1277        33.0       0.0
# 1278        24.0       0.0
# 1279        18.0       0.0
# 1280        24.0       0.0
#
# [1281 rows x 23 columns]

# %%
df_for_corr = df_num.drop(labels=['Failures'], axis=1)

# %%
normalized_df=(df_num-df_num.mean())/df_num.std()

# %%
normalized_df
# Out:
#       LOCATION  CUSTOMER       RIG  In hole hrs  Run Circ. Hrs.  Depth In  \
# 0    -0.283914 -1.132861 -0.619006     0.024743       -1.031516 -1.603560
# 1    -0.546509 -1.605778 -0.794232     0.025715       -0.475284  0.782121
# 2     0.258782  1.397248 -1.144682     0.025368       -0.746269 -1.609323
# 3    -0.038826  1.657352 -1.039547     0.028068        1.278987  0.720323
# 4    -1.579383 -0.896402 -1.127160     0.026322       -0.104462  0.649782
# ...        ...       ...       ...          ...             ...       ...
# 1276 -0.809104 -0.849110  0.782796     0.027086        0.580131 -0.314943
# 1277 -0.809104 -0.849110  0.782796     0.026322        0.023899  0.307806
# 1278 -0.809104 -0.849110  0.782796     0.025941       -0.617907  0.508103
# 1279 -0.809104 -0.849110  0.782796     0.025500       -0.717744  0.832592
# 1280 -0.809104 -0.849110  0.782796     0.025559       -0.632170  0.933337
#
#       Depth Out  Total Drilled       ROP       GPM      RPM:      SPM:  \
# 0     -1.988159      -0.887486  0.373200  0.231972 -1.215889  0.258071
# 1      0.621019      -0.209425  0.200535  0.566001  0.477350  0.576978
# 2     -0.986855       0.965332  3.826485  1.234060  0.477350  1.214792
# 3      1.651252       1.793501  0.155097  0.566001  0.759556  0.793012
# 4      0.410306      -0.368464 -0.281107  0.064957 -0.087063  0.093474
# ...         ...            ...       ...       ...       ...       ...
# 1276  -0.215859       0.146780 -0.235669  1.234060 -0.463338  0.978183
# 1277  -0.027356      -0.582805 -0.481034  1.083746  0.195143  0.844448
# 1278   0.277421      -0.368120  0.227798  1.083746 -0.519780  0.844448
# 1279   0.372046      -0.754897 -0.344720  1.013600 -0.256387  0.782724
# 1280   0.491680      -0.708868 -0.335633  0.231972 -0.275201  0.093474
#
#       Pump Press  Temp in F  Temp out F     Mud #    Inc In   Inc Out  \
# 0      -1.583371  -2.008761   -1.660781 -0.045872 -0.784866 -1.146925
# 1       1.522321   1.352813    1.037730 -0.011582  0.335093  1.138224
# 2      -0.630959  -2.008761   -0.394934 -0.039204 -0.784866 -1.032190
# 3       1.907427   1.618200    1.449866 -0.006819 -0.759237  1.083246
# 4       0.013250   1.544482    0.782598 -0.003961 -0.446572  0.892021
# ...          ...        ...         ...       ...       ...       ...
# 1276    0.469343  -0.077330   -0.149615 -0.033489 -0.682352 -1.058483
# 1277    0.845576   0.261776   -0.129990 -0.031108 -0.690041 -1.041751
# 1278    0.841435   0.291263   -0.159428 -0.033489 -0.672101 -1.058483
# 1279    0.871604   0.261776   -0.061300 -0.031584 -0.690041 -1.053703
# 1280    1.226541   0.394469    0.193832 -0.009200 -0.684915 -1.079996
#
#         Azm In   Azm out   Orifice  Pulse Ampl  Failures
# 0    -1.404083 -1.826291  0.921931   -0.869114  0.983852
# 1     0.804564  1.081760 -0.034631   -0.142414  0.983852
# 2    -1.404083  0.841202  0.921931    0.780691  0.983852
# 3     0.501258  1.146775 -0.034631   -0.437022  0.983852
# 4     0.859378 -0.712668 -0.034631    0.309319  0.983852
# ...        ...       ...       ...         ...       ...
# 1276 -0.598680 -0.864990  0.921931   -0.672708 -1.030094
# 1277 -0.647647 -0.829696  0.921931   -0.613787 -1.030094
# 1278 -0.619875 -0.984805  0.921931   -0.790551 -1.030094
# 1279 -0.647647 -0.951368  0.921931   -0.908395 -1.030094
# 1280 -0.715617 -0.876136  0.284223   -0.790551 -1.030094
#
# [1281 rows x 23 columns]

# %%
from sklearn.utils import shuffle
normalized_df = shuffle(normalized_df)

# %%
normalized_df.isnull().sum()
# Out:
# LOCATION          0
# CUSTOMER          0
# RIG               0
# In hole hrs       0
# Run Circ. Hrs.    0
# Depth In          0
# Depth Out         0
# Total Drilled     0
# ROP               0
# GPM               0
# RPM:              0
# SPM:              0
# Pump Press        0
# Temp in F         0
# Temp out F        0
# Mud #             0
# Inc In            0
# Inc Out           0
# Azm In            0
# Azm out           0
# Orifice           0
# Pulse Ampl        0
# Failures          0
# dtype: int64

# %%
df['Failures']=df['Failures'].astype(int)

# %%
sns.heatmap(normalized_df.corr())
# Out:
# <AxesSubplot:>

# %%
X = normalized_df.drop(labels=['Failures'], axis=1)
y = normalized_df['Failures']

# %%
X
# Out:
#       LOCATION  CUSTOMER       RIG  In hole hrs  Run Circ. Hrs.  Depth In  \
# 796   0.118731  0.971622 -0.478826     0.027528        0.796919  0.202293
# 477  -0.914142 -0.565360 -0.864322     0.025569       -0.689219 -1.608329
# 122   0.363820  0.735163 -1.284863     0.025784       -1.002991  1.805265
# 1042  0.853997  0.687872  0.660138     0.026947        0.123735  1.292799
# 328   1.571757 -0.305255 -1.687881     0.026270       -0.632170  0.465182
# ...        ...       ...       ...          ...             ...       ...
# 829  -1.404320 -0.636297  0.730229     0.026097       -0.147249 -1.016380
# 1024  0.451352 -0.305255  0.940499     0.028925        1.336036  0.827823
# 465   0.118731  0.971622  1.466175     0.027884        1.293249 -0.085038
# 844   0.556390  0.309538  0.449868     0.028127        1.100707 -0.065962
# 291  -1.684421 -1.085569 -0.110853     0.029268        1.678333  2.394433
#
#       Depth Out  Total Drilled       ROP       GPM      RPM:      SPM:  \
# 796    0.241213       0.093882 -0.308370 -0.770116 -0.087063 -0.780948
# 477   -0.997866       0.943348  3.081302  0.666210  0.853625  0.669564
# 122    1.191006      -0.929049 -0.726399 -1.772204 -1.215889 -1.655370
# 1042   1.679061       0.855069  0.409550  0.145124  0.853625  0.371232
# 328    0.046738      -0.718486 -0.353808  0.900030 -0.952496  0.895885
# ...         ...            ...       ...       ...       ...       ...
# 829    0.161893       2.054558  1.736339  0.265375  0.571418  0.504967
# 1024   1.455284       1.246998 -0.044830  0.188548  0.289212  0.422668
# 465   -0.523996      -0.817757 -0.690049  0.181867 -1.027751 -0.215146
# 844    0.255211       0.583364 -0.199319 -0.773456  0.101074 -0.924970
# 291    2.170101      -0.145535 -0.508297 -0.783477  0.101074 -0.780948
#
#       Pump Press  Temp in F  Temp out F     Mud #    Inc In   Inc Out  \
# 796    -0.074892   0.247032    0.046640 -0.027774 -0.546522  0.933373
# 477    -0.062469  -0.814518   -0.169241 -0.037299 -0.777177 -1.022629
# 122    -2.027041   0.851526    0.242895 -0.026822  1.478116  0.963730
# 1042    0.907098   0.468188    0.223270 -0.036823  1.524247  0.958950
# 328     0.061167   0.055363   -0.179053 -0.038252 -0.766926 -0.398754
# ...          ...        ...         ...       ...       ...       ...
# 829     1.125975  -2.008761    0.900351 -0.027774 -0.777177 -1.120632
# 1024    1.035467   0.482932    0.203644 -0.044920  1.539624  1.001975
# 465    -0.737440  -0.313230   -0.463624 -0.047777 -0.710543 -0.979842
# 844    -0.139372  -0.106818   -0.061300 -0.044920  1.109068  1.030659
# 291     0.313171   2.281669    1.194734 -0.034442  1.465302  1.052172
#
#         Azm In   Azm out   Orifice  Pulse Ampl
# 796  -0.552636  1.366899 -0.481026   -0.692349
# 477   1.165607  1.038107  0.921931    0.014711
# 122  -0.185746 -0.277993 -0.481026   -1.261924
# 1042  1.117370  1.356683 -0.481026   -0.476303
# 328   0.295888 -0.645795  0.284223    0.368240
# ...        ...       ...       ...         ...
# 829   1.117005  1.395692 -0.034631   -0.181695
# 1024 -0.196709 -0.288210 -0.481026   -0.790551
# 465  -1.223562  0.365660  0.284223   -0.181695
# 844  -1.355116 -1.780780 -0.672338   -0.338819
# 291  -0.215711 -0.293783 -0.672338   -0.358460
#
# [1281 rows x 22 columns]

# %% [markdown]
# ## Spliting  Data to train and test for Prediction, importing library to model the data.

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC, LinearSVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import Perceptron
from sklearn.linear_model import SGDClassifier
from sklearn.tree import DecisionTreeClassifier

# %%
print(X.shape)
print(y.shape)
# Out:
# (1281, 22)
# (1281,)

# %%
y=y.astype(int)
y
# Out:
# 796    -1
# 477     0
# 122     0
# 1042   -1
# 328     0
#        ..
# 829    -1
# 1024   -1
# 465     0
# 844    -1
# 291     0
# Name: Failures, Length: 1281, dtype: int32

# %% [markdown]
# ## Split the data 70 percent testing and 30 percent testing

# %%
# Train and val split

from sklearn.model_selection import GridSearchCV, train_test_split, StratifiedKFold
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, ExtraTreesClassifier

X_train, X_val, y_train, y_val = train_test_split(X, y, test_size = 0.3, random_state=42)

# %%
X_train.shape, y_train.shape, X_val.shape, y_val.shape
# Out:
# ((896, 22), (896,), (385, 22), (385,))

# %% [markdown]
# ## Modeling the data

# %%
print("train sample size",X_train.shape,type(X_train))
print("test sample size",X_val.shape,type(X_val))
# Out:
# train sample size (896, 22) <class 'pandas.core.frame.DataFrame'>
# test sample size (385, 22) <class 'pandas.core.frame.DataFrame'>

# %%
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, confusion_matrix, precision_recall_fscore_support

clf = SVC(kernel = 'linear').fit(X_train,y_train)
clf.predict(X_train)
y_pred = clf.predict(X_val)
y_training = clf.predict(X_train)

print('Training set score: {:.4f}'.format(clf.score(X_train, y_train)))
print('Test set score: {:.4f}'.format(clf.score(X_val, y_val)))
acc_svc = round(clf.score(X_val, y_val) * 100, 2)

cm = confusion_matrix(y_val, y_pred)
# Out:
# Training set score: 0.6786
# Test set score: 0.6753

# %%
print("y_test sample size",y_val.shape,type(y_val))
print("y_pred sample size",y_pred.shape,type(y_pred))
# Out:
# y_test sample size (385,) <class 'pandas.core.series.Series'>
# y_pred sample size (385,) <class 'numpy.ndarray'>

# %%
print(acc_svc)
print(cm)
# Out:
# 67.53
# [[121  67]
#  [ 58 139]]

# %%
print(acc_svc)
print(cm)
# Out:
# 67.53
# [[121  67]
#  [ 58 139]]

# %% [markdown]
# ## This is just to visual of the confusion matrix

# %%
from sklearn.metrics import plot_confusion_matrix

plot_confusion_matrix(clf, X_val, y_val)  
plt.show()

# %%
# Support Vector Machines

svc = SVC(kernel = 'linear').fit(X_train,y_train)
svc.fit(X_train, y_train)
svc.predict(X_train)
y_pred = svc.predict(X_val)
y_training = svc.predict(X_train)

print('Training set score: {:.4f}'.format(svc.score(X_train, y_train)))
print('Test set score: {:.4f}'.format(svc.score(X_val, y_val)))
acc_svc = round(svc.score(X_val, y_val) * 100, 2)
acc_svc

cm = confusion_matrix(y_val, y_pred)
# Out:
# Training set score: 0.6786
# Test set score: 0.6753

# %%
print(acc_svc)
print(cm)
# Out:
# 67.53
# [[121  67]
#  [ 58 139]]

# %%
plot_confusion_matrix(svc, X_val, y_val)  
plt.show()

# %%
logreg = LogisticRegression()
logreg.fit(X_train, y_train)
y_pred = logreg.predict(X_val)
y_training = logreg.predict(X_train)

print('Training set score: {:.4f}'.format(logreg.score(X_train, y_train)))
print('Test set score: {:.4f}'.format(logreg.score(X_val, y_val)))
acc_log = round(logreg.score(X_val, y_val) * 100, 2)
acc_log

cm = confusion_matrix(y_val, y_pred)
# Out:
# Training set score: 0.6663
# Test set score: 0.6909

# %%
print(acc_log)
print(cm)
# Out:
# 69.09
# [[119  69]
#  [ 50 147]]

# %%
plot_confusion_matrix(logreg, X_val, y_val)  
plt.show()

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn = KNeighborsClassifier(n_neighbors = 3)
knn.fit(X_train, y_train)
y_pred = knn.predict(X_val)
y_training = knn.predict(X_train)

print('Training set score: {:.4f}'.format(knn.score(X_train, y_train)))
print('Test set score: {:.4f}'.format(knn.score(X_val, y_val)))
acc_knn = round(knn.score(X_val, y_val) * 100, 2)
acc_knn

cm = confusion_matrix(y_val, y_pred)
# Out:
# Training set score: 0.8504
# Test set score: 0.7558

# %%
print(acc_knn)
print(cm)
# Out:
# 75.58
# [[151  37]
#  [ 57 140]]

# %%
plot_confusion_matrix(knn, X_val, y_val)  
plt.show()

# %%
# Random Forest
from sklearn.ensemble import RandomForestClassifier

random_forest = RandomForestClassifier(n_estimators=100,criterion='gini',max_depth=None,min_samples_split=2, min_samples_leaf=1, min_weight_fraction_leaf=0.0, max_features='auto', max_leaf_nodes=None,bootstrap=True, oob_score=False, n_jobs=1, random_state=None, verbose=0, warm_start=False,class_weight=None)
random_forest.fit(X_train, y_train)
y_pred = random_forest.predict(X_val)
y_training = random_forest.predict(X_train)
random_forest.score(X_train, y_train)

print('Training set score: {:.4f}'.format(random_forest.score(X_train, y_train)))
print('Test set score: {:.4f}'.format(random_forest.score(X_val, y_val)))
acc_random_forest = round(random_forest.score(X_val, y_val) * 100, 2)
acc_random_forest

cm = confusion_matrix(y_val, y_pred)
# Out:
# Training set score: 1.0000
# Test set score: 0.7896

# %%
print(acc_random_forest)
print(cm)
# Out:
# 78.96
# [[152  36]
#  [ 45 152]]

# %%
plot_confusion_matrix(random_forest, X_val, y_val)  
plt.show()

# %%
gaussian = GaussianNB()
gaussian.fit(X_train, y_train)
Y_pred = gaussian.predict(X_val)
Y_training = gaussian.predict(X_train)

print('Training set score: {:.4f}'.format(gaussian.score(X_train, y_train)))
print('Test set score: {:.4f}'.format(gaussian.score(X_val, y_val)))
acc_gaussian = round(gaussian.score(X_val, y_val) * 100, 2)
acc_gaussian
# Out:
# Training set score: 0.5670
# Test set score: 0.5610
# 56.1

# %%
plot_confusion_matrix(gaussian, X_val, y_val)  
plt.show()

# %%
perceptron = Perceptron()
perceptron.fit(X_train, y_train)
Y_pred = perceptron.predict(X_val)
Y_training = perceptron.predict(X_train)
print('Training set score: {:.4f}'.format(perceptron.score(X_train, y_train)))
print('Test set score: {:.4f}'.format(perceptron.score(X_val, y_val)))

acc_perceptron = round(perceptron.score(X_val, y_val) * 100, 2)
acc_perceptron
# Out:
# Training set score: 0.6016
# Test set score: 0.6026
# 60.26

# %%
plot_confusion_matrix(perceptron, X_val, y_val)  
plt.show()

# %%
linear_svc = LinearSVC()
linear_svc.fit(X_train, y_train)
Y_pred = linear_svc.predict(X_val)

print('Training set score: {:.4f}'.format(linear_svc.score(X_train, y_train)))
print('Test set score: {:.4f}'.format(linear_svc.score(X_val, y_val)))
acc_linear_svc = round(linear_svc.score(X_val, y_val) * 100, 2)
acc_linear_svc
# Out:
# Training set score: 0.6629
# Test set score: 0.6935
# C:\Users\adeni\anaconda3\lib\site-packages\sklearn\svm\_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# 69.35

# %%
plot_confusion_matrix(linear_svc, X_val, y_val)  
plt.show()

# %%
sgd = SGDClassifier()
sgd.fit(X_train, y_train)
Y_pred = sgd.predict(X_val)
Y_training = sgd.predict(X_train)

print('Training set score: {:.4f}'.format(sgd.score(X_train, y_train)))
print('Test set score: {:.4f}'.format(sgd.score(X_val, y_val)))
acc_sgd = round(sgd.score(X_val, y_val) * 100, 2)
# Out:
# Training set score: 0.6172
# Test set score: 0.6468

# %%
plot_confusion_matrix(sgd, X_val, y_val)  
plt.show()

# %%
decision_tree = DecisionTreeClassifier()
decision_tree.fit(X_train, y_train)
Y_pred = decision_tree.predict(X_val)

print('Training set score: {:.4f}'.format(decision_tree.score(X_train, y_train)))
print('Test set score: {:.4f}'.format(decision_tree.score(X_val, y_val)))
acc_decision_tree = round(decision_tree.score(X_val, y_val) * 100, 2)
acc_decision_tree
# Out:
# Training set score: 1.0000
# Test set score: 0.7455
# 74.55

# %%
plot_confusion_matrix(decision_tree, X_val, y_val)  
plt.show()

# %%
from sklearn import tree 
tree.plot_tree(decision_tree)
plt.show()

# %%
len(df.columns)
# Out:
# 59

# %%
# fig, ax = plt.subplots(figsize=(10,10))
# out = tree.plot_tree(decision_tree, filled=True, rounded=True,
#                     feature_names = [])

# %%
decision_tree = DecisionTreeClassifier(criterion = 'gini', random_state=0)
decision_tree.fit(X_train, y_train)
Y_pred = decision_tree.predict(X_val)
Y_training = decision_tree.predict(X_train)

print('Training set score: {:.4f}'.format(decision_tree.score(X_train, y_train)))
print('Test set score: {:.4f}'.format(decision_tree.score(X_val, y_val)))
acc_decision_tree = round(decision_tree.score(X_val, y_val) * 100, 2)
# Out:
# Training set score: 1.0000
# Test set score: 0.7429

# %% [markdown]
# ### Deep Learning with Keras

# %%
df_num
# Out:
#       LOCATION  CUSTOMER  RIG  In hole hrs  Run Circ. Hrs.  Depth In  \
# 0          100        30   65          2.0             1.0       109
# 1           85        10   55         30.0            20.5     12115
# 2          131       137   35         20.0            11.0        80
# 3          114       148   41         97.8            82.0     11804
# 4           26        40   36         47.5            33.5     11449
# ...        ...       ...  ...          ...             ...       ...
# 1276        70        42  145         69.5            57.5      6594
# 1277        70        42  145         47.5            38.0      9728
# 1278        70        42  145         36.5            15.5     10736
# 1279        70        42  145         23.8            12.0     12369
# 1280        70        42  145         25.5            15.0     12876
#
#       Depth Out  Total Drilled    ROP  GPM  RPM:   SPM:  Pump Press  \
# 0         230.0          121.0  121.0  600     0  186.0         750
# 1       14210.0         2095.0  102.0  700    90  217.0        6000
# 2        5595.0         5515.0  501.0  900    90  279.0        2360
# 3       19730.0         7926.0   97.0  700   105  238.0        6651
# 4       13081.0         1632.0   49.0  550    60  170.0        3449
# ...         ...            ...    ...  ...   ...    ...         ...
# 1276     9726.0         3132.0   54.0  900    40  256.0        4220
# 1277    10736.0         1008.0   27.0  855    75  243.0        4856
# 1278    12369.0         1633.0  105.0  855    37  243.0        4849
# 1279    12876.0          507.0   42.0  834    51  237.0        4900
# 1280    13517.0          641.0   43.0  600    50  170.0        5500
#
#       Temp in F  Temp out F  Mud #  Inc In  Inc Out  Azm In  Azm out  Orifice  \
# 0           0.0         0.0   8.50     0.0      0.0     0.0      0.0     1.50
# 1         228.0       275.0  12.10    43.7     95.6   302.2    313.1     1.35
# 2           0.0       129.0   9.20     0.0      4.8     0.0    287.2     1.50
# 3         246.0       317.0  12.60     1.0     93.3   260.7    320.1     1.35
# 4         241.0       249.0  12.90    13.2     85.3   309.7    119.9     1.35
# ...         ...         ...    ...     ...      ...     ...      ...      ...
# 1276      131.0       154.0   9.80     4.0      3.7   110.2    103.5     1.50
# 1277      154.0       156.0  10.05     3.7      4.4   103.5    107.3     1.50
# 1278      156.0       153.0   9.80     4.4      3.7   107.3     90.6     1.50
# 1279      154.0       163.0  10.00     3.7      3.9   103.5     94.2     1.50
# 1280      163.0       189.0  12.35     3.9      2.8    94.2    102.3     1.40
#
#       Pulse Ampl  Failures
# 0           20.0       1.0
# 1           57.0       1.0
# 2          104.0       1.0
# 3           42.0       1.0
# 4           80.0       1.0
# ...          ...       ...
# 1276        30.0       0.0
# 1277        33.0       0.0
# 1278        24.0       0.0
# 1279        18.0       0.0
# 1280        24.0       0.0
#
# [1281 rows x 23 columns]

# %%
df_num = df_num.values

# %%
df_num
# Out:
# array([[100.  ,  30.  ,  65.  , ...,   1.5 ,  20.  ,   1.  ],
#        [ 85.  ,  10.  ,  55.  , ...,   1.35,  57.  ,   1.  ],
#        [131.  , 137.  ,  35.  , ...,   1.5 , 104.  ,   1.  ],
#        ...,
#        [ 70.  ,  42.  , 145.  , ...,   1.5 ,  24.  ,   0.  ],
#        [ 70.  ,  42.  , 145.  , ...,   1.5 ,  18.  ,   0.  ],
#        [ 70.  ,  42.  , 145.  , ...,   1.4 ,  24.  ,   0.  ]])

# %%
X=df_num[:,0:21]

# %%
X
# Out:
# array([[100.  ,  30.  ,  65.  , ...,   0.  ,   0.  ,   1.5 ],
#        [ 85.  ,  10.  ,  55.  , ..., 302.2 , 313.1 ,   1.35],
#        [131.  , 137.  ,  35.  , ...,   0.  , 287.2 ,   1.5 ],
#        ...,
#        [ 70.  ,  42.  , 145.  , ..., 107.3 ,  90.6 ,   1.5 ],
#        [ 70.  ,  42.  , 145.  , ..., 103.5 ,  94.2 ,   1.5 ],
#        [ 70.  ,  42.  , 145.  , ...,  94.2 , 102.3 ,   1.4 ]])

# %%
y=df_num[:,21]

# %%
y
# Out:
# array([ 20.,  57., 104., ...,  24.,  18.,  24.])

# %%
from sklearn import preprocessing

# %%
min_max_scaler = preprocessing.MinMaxScaler()
X_scale = min_max_scaler.fit_transform(X)

# %%
X_scale
# Out:
# array([[0.4587156 , 0.1863354 , 0.32338308, ..., 0.        , 0.        ,
#         0.42857143],
#        [0.38990826, 0.0621118 , 0.27363184, ..., 0.10195682, 0.86996388,
#         0.38571429],
#        [0.60091743, 0.85093168, 0.17412935, ..., 0.        , 0.79799944,
#         0.42857143],
#        ...,
#        [0.32110092, 0.26086957, 0.72139303, ..., 0.03620108, 0.25173659,
#         0.42857143],
#        [0.32110092, 0.26086957, 0.72139303, ..., 0.03491903, 0.26173937,
#         0.42857143],
#        [0.32110092, 0.26086957, 0.72139303, ..., 0.03178138, 0.28424562,
#         0.4       ]])

# %%
from sklearn.model_selection import train_test_split
X_train, X_val_and_test, Y_train, Y_val_and_test = train_test_split(X_scale, y, test_size=0.3)
X_val, X_test, Y_val, Y_test = train_test_split(X_val_and_test, Y_val_and_test, test_size=0.5)

# %%
print(X_train.shape, X_val.shape, X_test.shape, Y_train.shape, Y_val.shape, Y_test.shape)
# Out:
# (896, 21) (192, 21) (193, 21) (896,) (192,) (193,)

# %%
from keras.models import Sequential
from keras.layers import Dense

model = Sequential([
    Dense(32, activation='relu', input_shape=(21,)),
    Dense(32, activation='relu'),
    Dense(1, activation='sigmoid'),
])

# model = Sequential()
# model.add(Dense(32, input_dim=20, activation='relu'))
# model.add(Dense(32, activation='relu'))
# model.add(Dense(1, activation='linear'))

# model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
# # fit the keras model on the dataset
# model.fit(X, y, epochs=10, batch_size=10)

# accuracy = model.evaluate(X, y)
# print('Accuracy: %.2f',(accuracy*100))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-100-16641622c1af> in <module>
# ----> 1 from keras.models import Sequential
#       2 from keras.layers import Dense
#       3
#       4 model = Sequential([
#       5     Dense(32, activation='relu', input_shape=(21,)),
#
# ModuleNotFoundError: No module named 'keras'

# %%
model.compile(optimizer='sgd',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %%
hist = model.fit(X_train, Y_train,
          batch_size=32, epochs=10,
          validation_data=(X_val, Y_val))

# %%
model.evaluate(X_test, Y_test)[1]

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper right')
plt.show()

# %% [markdown]
# ## This the correlation of the features (Very Important)

# %%
coeff_df = pd.DataFrame(normalized_df.columns.delete(21))
coeff_df.columns = ['Feature']
coeff_df["Correlation"] = pd.Series(logreg.coef_[0])

coeff_df.sort_values(by='Correlation', ascending=False)
# Out:
#            Feature  Correlation
# 14      Temp out F     0.657003
# 17         Inc Out     0.396861
# 9              GPM     0.198556
# 13       Temp in F     0.146725
# 16          Inc In     0.136884
# 15           Mud #     0.062304
# 18          Azm In     0.051632
# 20         Orifice     0.007699
# 8              ROP    -0.030920
# 10            RPM:    -0.083105
# 3      In hole hrs    -0.115304
# 7    Total Drilled    -0.117091
# 2              RIG    -0.174242
# 21        Failures    -0.174837
# 19         Azm out    -0.182547
# 1         CUSTOMER    -0.196376
# 5         Depth In    -0.200277
# 11            SPM:    -0.217703
# 0         LOCATION    -0.283610
# 6        Depth Out    -0.338224
# 12      Pump Press    -0.371229
# 4   Run Circ. Hrs.    -0.406037

# %% [markdown]
# ## Model evaluation

# %%
models = pd.DataFrame({
    'Model': ['Support Vector Machines', 'KNN', 'Logistic Regression', 
              'Random Forest', 'Naive Bayes', 'Perceptron', 
              'Stochastic Gradient Decent', 'Linear SVC', 
              'Decision Tree'],
    'Score': [acc_svc, acc_knn, acc_log, 
              acc_random_forest, acc_gaussian, acc_perceptron, 
              acc_sgd, acc_linear_svc, acc_decision_tree]})
models.sort_values(by='Score', ascending=False)
# Out:
#                         Model  Score
# 3               Random Forest  78.96
# 1                         KNN  75.58
# 8               Decision Tree  74.29
# 7                  Linear SVC  69.35
# 2         Logistic Regression  69.09
# 0     Support Vector Machines  67.53
# 6  Stochastic Gradient Decent  64.68
# 5                  Perceptron  60.26
# 4                 Naive Bayes  56.10

# %% [markdown]
# ## Export the numerical Data to be further explored in the Spotfire

# %%
df_num.to_excel(r'2018_MWD_summary.xlsx', index = False)
